# %%
# Francisco Dominguez Mateos
# 04/07/2020
# from: https://github.com/google/jax/pull/1196/commits/d9ee85274c5b75054a3aad1f44b28e08f685ac70
#       https://github.com/google/jax/pull/1196

# %%
#!conda install -c pytorch pytorch --yes
#!conda install -c pytorch torchvision --yes
#!conda install -c anaconda seaborn --yes

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
import numpy as onp
import jax.numpy as np
from jax import grad, jit, vmap, value_and_grad
from jax import random

from jax.nn import sigmoid
from jax.nn.initializers import glorot_normal, normal

from functools import partial
from jax import lax

from jax.experimental import stax
from jax.experimental.stax import (BatchNorm, Conv, Dense, Flatten,
                                   Relu, LogSoftmax)

# %%
# Import some additional JAX and dataloader helpers
from jax.scipy.special import logsumexp
from jax.experimental import optimizers

import torch
from torchvision import datasets, transforms

import time
#from: https://github.com/RobertTLange/code-and-blog/blob/master/04_jax_intro/helpers.py
#!conda install -c anaconda seaborn --yes
from helpers import plot_mnist_examples

# %%
# Generate key which is used to generate random numbers
key = random.PRNGKey(1)

# %%
# Generate & plot a time series generated by the OU process
from helpers import generate_ou_process, plot_ou_process
x_0, mu, tau, sigma, dt = 0, 1, 2, 0.5, 0.1
noise_std = 0.1
num_dims, batch_size = 100, 50  # Number of timesteps in process

x, x_tilde = generate_ou_process(batch_size, num_dims, mu, tau,
                                 sigma, noise_std, dt)
print(x.shape,x_tilde.shape)
plot_ou_process(x[ 0, :], x_tilde[ 0, :])
plot_ou_process(x[49, :], x_tilde[49, :])
# Out:
# (50, 100) (50, 100)

# %%
def LSTM(out_dim, W_init = glorot_normal(), b_init = normal()):
  def init_fun(rng, input_shape):
    in_dim=input_shape[-1]
    k1, k2 = random.split(rng)
    cell, hidden = b_init(k1, (out_dim,)), b_init(k2, (out_dim,)) 

    k1, k2, k3 = random.split(k1, num=3)
    forget_W = W_init(k1, (in_dim, out_dim))
    forget_U = W_init(k2, (out_dim, out_dim))
    forget_b = b_init(k3, (out_dim,)) 

    k1, k2, k3 = random.split(k1, num=3)
    in_W = W_init(k1, (in_dim, out_dim))
    in_U = W_init(k2, (out_dim, out_dim))
    in_b = b_init(k3, (out_dim,)) 

    k1, k2, k3 = random.split(k1, num=3)
    out_W = W_init(k1, (in_dim, out_dim))
    out_U = W_init(k2, (out_dim, out_dim))
    out_b = b_init(k3, (out_dim,)) 

    k1, k2, k3 = random.split(k1, num=3)    
    change_W = W_init(k1, (in_dim, out_dim)) 
    change_U = W_init(k2, (out_dim, out_dim))
    change_b = b_init(k3, (out_dim,)) 

    output_shape =  input_shape[:-1] + (out_dim,)
    return output_shape, ((cell, hidden), (forget_W, forget_U, forget_b), (in_W, in_U, in_b),
                           (out_W, out_U, out_b), (change_W, change_U, change_b))

  def apply_fun_scan(params, h, inputs):
    old_cell, hidden = h
    """ Perform single step update of the network """
    _, (forget_W, forget_U, forget_b), (in_W, in_U, in_b), (out_W, out_U, out_b), (
        change_W, change_U, change_b) = params
    input_gate  = sigmoid(np.dot(inputs, in_W    ) + np.dot(hidden, in_U    ) + in_b)
    forget_gate = sigmoid(np.dot(inputs, forget_W) + np.dot(hidden, forget_U) + forget_b)
    output_gate = sigmoid(np.dot(inputs, out_W   ) + np.dot(hidden, out_U   ) + out_b)
    change_gate = np.tanh(np.dot(inputs, change_W) + np.dot(hidden, change_U) + change_b)

    cell = np.multiply(change_gate, input_gate) + np.multiply(old_cell, forget_gate) 

    #this is hidden output
    output = np.multiply(output_gate, np.tanh(cell))

    return (output, cell), output
        
  def apply_fun(params, inputs, **kwargs):
    h = params[0]

    # Move the time dimension to position 0
    inputs = np.moveaxis(inputs, 1, 0)
    f = partial(apply_fun_scan, params)
    _, h_new = lax.scan(f, h, inputs)
    print(inputs.shape)
    print(h_new.shape)
    return h_new

  return init_fun, apply_fun

# %%
def GRU(out_dim, W_init=glorot_normal(), b_init=normal()):
    def init_fun(rng, input_shape):
        """ Initialize the GRU layer for stax """
        hidden = b_init(rng, (input_shape[0], out_dim))

        k1, k2, k3 = random.split(rng, num=3)
        update_W, update_U, update_b = (
            W_init(k1, (input_shape[2], out_dim)),
            W_init(k2, (out_dim, out_dim)),
            b_init(k3, (out_dim,)),)

        k1, k2, k3 = random.split(rng, num=3)
        reset_W, reset_U, reset_b = (
            W_init(k1, (input_shape[2], out_dim)),
            W_init(k2, (out_dim, out_dim)),
            b_init(k3, (out_dim,)),)

        k1, k2, k3 = random.split(rng, num=3)
        out_W, out_U, out_b = (
            W_init(k1, (input_shape[2], out_dim)),
            W_init(k2, (out_dim, out_dim)),
            b_init(k3, (out_dim,)),)
        # Input dim 0 represents the batch dimension
        # Input dim 1 represents the time dimension (before scan moveaxis)
        output_shape = (input_shape[0], input_shape[1], out_dim)
        return (output_shape,
            (hidden,
             (update_W, update_U, update_b),
             (reset_W, reset_U, reset_b),
             (out_W, out_U, out_b),),)

    def apply_fun(params, inputs, **kwargs):
        """ Loop over the time steps of the input sequence """
        # first parameter is hidden look up at init_fun
        h = params[0]

        def apply_fun_scan(params, hidden, inp):
            """ Perform single step update of the network """
            _, (update_W, update_U, update_b), (reset_W, reset_U, reset_b), (
                out_W, out_U, out_b) = params

            update_gate = sigmoid(np.dot(inp, update_W) +
                                  np.dot(hidden, update_U) + update_b)
            reset_gate = sigmoid(np.dot(inp, reset_W) +
                                 np.dot(hidden, reset_U) + reset_b)
            output_gate = np.tanh(np.dot(inp, out_W)
                                  + np.dot(np.multiply(reset_gate, hidden), out_U)
                                  + out_b)
            output = np.multiply(update_gate, hidden) + np.multiply(1-update_gate, output_gate)
            hidden = output
            return hidden, hidden

        # Move the time dimension to position 0
        inputs = np.moveaxis(inputs, 1, 0)
        f = partial(apply_fun_scan, params)
        _, h_new = lax.scan(f, h, inputs)
        print(inputs.shape)
        print(h_new.shape)
        return h_new

    return init_fun, apply_fun

# %%
num_dims = 100              # Number of OU timesteps
batch_size = 64            # Batchsize
num_hidden_units = 128      # GRU cells in the RNN layer

# Initialize the network and perform a forward pass
init_fun, gru_rnn = stax.serial(Dense(num_hidden_units), Relu,
                                LSTM(num_hidden_units), Dense(1))
_, params = init_fun(key, (batch_size, num_dims, 1))

# %%
def mse_loss(params, inputs, targets):
    """ Calculate the Mean Squared Error Prediction Loss. """
    preds = gru_rnn(params, inputs)
    print(inputs.shape,targets.shape,preds.shape)
    return np.mean((preds - targets)**2)

@jit
def update(params, x, y, opt_state):
    """ Perform a forward pass, calculate the MSE & perform a SGD step. """
    loss, grads = value_and_grad(mse_loss)(params, x, y)
    opt_state = opt_update(0, grads, opt_state)
    return get_params(opt_state), opt_state, loss

# %%
step_size = 1e-4
opt_init, opt_update, get_params = optimizers.adam(step_size)
opt_state = opt_init(params)

# %%
num_batches = 1000

train_loss_log = []
start_time = time.time()
for batch_idx in range(num_batches):
    x, x_tilde = generate_ou_process(batch_size, num_dims, mu, tau, sigma, noise_std)
    x_in = np.expand_dims(x_tilde[:, :(num_dims-1)], 2)
    y = np.array(x[:, 1:])
    params, opt_state, loss = update(params, x_in, y, opt_state)
    batch_time = time.time() - start_time
    train_loss_log.append(loss)

    if batch_idx % 100 == 0:
        start_time = time.time()
        print("Batch {} | T: {:0.2f} | MSE: {:0.2f} |".format(batch_idx, batch_time, loss))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-ef2b65ce7744> in <module>
#       7     x_in = np.expand_dims(x_tilde[:, :(num_dims-1)], 2)
#       8     y = np.array(x[:, 1:])
# ----> 9     params, opt_state, loss = update(params, x_in, y, opt_state)
#      10     batch_time = time.time() - start_time
#      11     train_loss_log.append(loss)
#
# ~/anaconda3/envs/jax_gpu/lib/python3.7/site-packages/jax/api.py in f_jitted(*args, **kwargs)
#     168     flat_fun, out_tree = flatten_fun(f, in_tree)
#     169     out = xla.xla_call(flat_fun, *args_flat, device=device, backend=backend,
# --> 170                        name=flat_fun.__name__, donated_invars=donated_invars)
#     171     return tree_unflatten(out_tree(), out)
#     172
#
# ~/anaconda3/envs/jax_gpu/lib/python3.7/site-packages/jax/core.py in call_bind(primitive, fun, *args, **params)
#    1098   if top_trace is None:
#    1099     with new_sublevel():
# -> 1100       outs = primitive.impl(fun, *args, **params)
#    1101   else:
#    1102     tracers = map(top_trace.full_raise, args)
#
# ~/anaconda3/envs/jax_gpu/lib/python3.7/site-packages/jax/interpreters/xla.py in _xla_call_impl(fun, device, backend, name, donated_invars, *args)
#     540 def _xla_call_impl(fun: lu.WrappedFun, *args, device, backend, name, donated_invars):
#     541   compiled_fun = _xla_callable(fun, device, backend, name, donated_invars,
# --> 542                                *unsafe_map(arg_spec, args))
#     543   try:
#     544     return compiled_fun(*args)
#
# ~/anaconda3/envs/jax_gpu/lib/python3.7/site-packages/jax/linear_util.py in memoized_fun(fun, *args)
#     219       fun.populate_stores(stores)
#     220     else:
# --> 221       ans = call(fun, *args)
#     222       cache[key] = (ans, fun.stores)
#     223     return ans
#
# ~/anaconda3/envs/jax_gpu/lib/python3.7/site-packages/jax/interpreters/xla.py in _xla_callable(fun, device, backend, name, donated_invars, *arg_specs)
#     606   pvals: Sequence[pe.PartialVal] = [pe.PartialVal.unknown(aval) for aval in abstract_args]
#     607   jaxpr, pvals, consts = pe.trace_to_jaxpr(
# --> 608       fun, pvals, instantiate=False, stage_out=True, bottom=True)
#     609   map(prefetch, it.chain(consts, jaxpr_literals(jaxpr)))
#     610   jaxpr, uses_outfeed = apply_outfeed_rewriter(jaxpr)
#
# ~/anaconda3/envs/jax_gpu/lib/python3.7/site-packages/jax/interpreters/partial_eval.py in trace_to_jaxpr(fun, pvals, instantiate, stage_out, bottom, trace_type)
#     427   with new_master(trace_type, bottom=bottom) as master:
#     428     fun = trace_to_subjaxpr(fun, master, instantiate)
# --> 429     jaxpr, (out_pvals, consts, env) = fun.call_wrapped(pvals)
#     430     assert not env
#     431     del master
#
# ~/anaconda3/envs/jax_gpu/lib/python3.7/site-packages/jax/linear_util.py in call_wrapped(self, *args, **kwargs)
#     148     gen = None
#     149
# --> 150     ans = self.f(*args, **dict(self.params, **kwargs))
#     151     del args
#     152     while stack:
#
# <ipython-input-20-b6ded194cabf> in update(params, x, y, opt_state)
#       8 def update(params, x, y, opt_state):
#       9     """ Perform a forward pass, calculate the MSE & perform a SGD step. """
# ---> 10     loss, grads = value_and_grad(mse_loss)(params, x, y)
#      11     opt_state = opt_update(0, grads, opt_state)
#      12     return get_params(opt_state), opt_state, loss
#
# ~/anaconda3/envs/jax_gpu/lib/python3.7/site-packages/jax/api.py in value_and_grad_f(*args, **kwargs)
#     469     tree_map(partial(_check_input_dtype_grad, holomorphic), dyn_args)
#     470     if not has_aux:
# --> 471       ans, vjp_py = _vjp(f_partial, *dyn_args)
#     472     else:
#     473       ans, vjp_py, aux = _vjp(f_partial, *dyn_args, has_aux=True)
#
# ~/anaconda3/envs/jax_gpu/lib/python3.7/site-packages/jax/api.py in _vjp(fun, *primals, **kwargs)
#    1553   if not has_aux:
#    1554     flat_fun, out_tree = flatten_fun_nokwargs(fun, in_tree)
# -> 1555     out_primal, out_vjp = ad.vjp(flat_fun, primals_flat)
#    1556     out_tree = out_tree()
#    1557   else:
#
# ~/anaconda3/envs/jax_gpu/lib/python3.7/site-packages/jax/interpreters/ad.py in vjp(traceable, primals, has_aux)
#     107 def vjp(traceable, primals, has_aux=False):
#     108   if not has_aux:
# --> 109     out_primals, pvals, jaxpr, consts = linearize(traceable, *primals)
#     110   else:
#     111     out_primals, pvals, jaxpr, consts, aux = linearize(traceable, *primals, has_aux=True)
#
# ~/anaconda3/envs/jax_gpu/lib/python3.7/site-packages/jax/interpreters/ad.py in linearize(traceable, *primals, **kwargs)
#      94   _, in_tree = tree_flatten(((primals, primals), {}))
#      95   jvpfun_flat, out_tree = flatten_fun(jvpfun, in_tree)
# ---> 96   jaxpr, out_pvals, consts = pe.trace_to_jaxpr(jvpfun_flat, in_pvals)
#      97   out_primals_pvals, out_tangents_pvals = tree_unflatten(out_tree(), out_pvals)
#      98   assert all(out_primal_pval.is_known() for out_primal_pval in out_primals_pvals)
#
# ~/anaconda3/envs/jax_gpu/lib/python3.7/site-packages/jax/interpreters/partial_eval.py in trace_to_jaxpr(fun, pvals, instantiate, stage_out, bottom, trace_type)
#     427   with new_master(trace_type, bottom=bottom) as master:
#     428     fun = trace_to_subjaxpr(fun, master, instantiate)
# --> 429     jaxpr, (out_pvals, consts, env) = fun.call_wrapped(pvals)
#     430     assert not env
#     431     del master
#
# ~/anaconda3/envs/jax_gpu/lib/python3.7/site-packages/jax/linear_util.py in call_wrapped(self, *args, **kwargs)
#     148     gen = None
#     149
# --> 150     ans = self.f(*args, **dict(self.params, **kwargs))
#     151     del args
#     152     while stack:
#
# <ipython-input-20-b6ded194cabf> in mse_loss(params, inputs, targets)
#       1 def mse_loss(params, inputs, targets):
#       2     """ Calculate the Mean Squared Error Prediction Loss. """
# ----> 3     preds = gru_rnn(params, inputs)
#       4     print(inputs.shape,targets.shape,preds.shape)
#       5     return np.mean((preds - targets)**2)
#
# ~/anaconda3/envs/jax_gpu/lib/python3.7/site-packages/jax/experimental/stax.py in apply_fun(params, inputs, **kwargs)
#     300     rngs = random.split(rng, nlayers) if rng is not None else (None,) * nlayers
#     301     for fun, param, rng in zip(apply_funs, params, rngs):
# --> 302       inputs = fun(param, inputs, rng=rng, **kwargs)
#     303     return inputs
#     304   return init_fun, apply_fun
#
# <ipython-input-18-606bceb71003> in apply_fun(params, inputs, **kwargs)
#      52     inputs = np.moveaxis(inputs, 1, 0)
#      53     f = partial(apply_fun_scan, params)
# ---> 54     _, h_new = lax.scan(f, h, inputs)
#      55     print(inputs.shape)
#      56     print(h_new.shape)
#
# ~/anaconda3/envs/jax_gpu/lib/python3.7/site-packages/jax/lax/lax_control_flow.py in scan(f, init, xs, length, reverse)
#    1220                         # Extract the subtree and avals for the first element of the return tuple
#    1221                         out_tree_children[0], jaxpr.out_avals[:out_tree_children[0].num_leaves],
# -> 1222                         init_tree, carry_avals)
#    1223
#    1224   out = scan_p.bind(*itertools.chain(consts, in_flat),
#
# ~/anaconda3/envs/jax_gpu/lib/python3.7/site-packages/jax/lax/lax_control_flow.py in _check_tree_and_avals(what, tree1, avals1, tree2, avals2)
#    1706            "got\n{}\nand\n{}.")
#    1707     raise TypeError(msg.format(what, tree_unflatten(tree1, avals1),
# -> 1708                                tree_unflatten(tree2, avals2)))
#    1709
#    1710
#
# TypeError: scan carry output and input must have identical types, got
# (ShapedArray(float32[64,128]), ShapedArray(float32[64,128]))
# and
# (ShapedArray(float32[128]), ShapedArray(float32[128])).

# %%
# Plot the training loss for OU-GRU-RNN!
from helpers import plot_ou_loss
plot_ou_loss(train_loss_log)

# %%
# Plot a prediction and ground truth OU process
x_true, x_tilde = generate_ou_process(batch_size, num_dims, mu, tau, sigma, noise_std)
x = np.expand_dims(x_tilde[:, :(num_dims-1)], 2)
y = np.array(x[:, 1:])
preds = gru_rnn(params, x)

x = onp.array(x)
y = onp.array(y)
x_pred = onp.array(preds)
plot_ou_process(x_true[:, 0], x_tilde=x_tilde[:, 0], x_pred=x_pred[0, :],
               title=r"Ornstein-Uhlenbeck Prediction")
# Out:
# (99, 64, 128)
# (99, 64, 128)
