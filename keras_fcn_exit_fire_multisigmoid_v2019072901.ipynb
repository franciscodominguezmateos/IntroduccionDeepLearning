# %%
# Kernel dl
# Initial code and auxiliar functions. Don't pay attention to this
import os
import random
import numpy as np
import matplotlib.pyplot as plt
import cv2

# Config the matplotlib backend as plotting inline in IPython
# %matplotlib inline

# %%
# pip install untangle
# The easiest way to parse xml files I have found.
import untangle

# %%
# dlib image object detection dataset xml file format
basepath='/home/francisco/Pictures/datasets/indoor_object_detection_dataset/faster_bounding_box_dataset/all'
filename='exit_fire.xml'
obj=untangle.parse(filename)
len(obj.dataset.images.image)
# Out:
# 1086

# %%
def fillRec(img,x,y,w,h):
    for i in range(w-1):
        for j in range(h-1):
            img[y+j+1,x+i+1,0]=1

def fillRecSoftMax(img,x,y,w,h,label):
    for i in range(w+1):
        for j in range(h+1):
            nx=x+i
            if nx==img.shape[1]: nx-=1
            ny=y+j
            if ny==img.shape[0]: ny-=1
            img[ny,nx,0]=0
            img[ny,nx,label]=1
            
def setCenter(img,top,left,width,height):
    center_x=left+width//2
    center_y=top +height//2
    y[center_y,center_x,0]=1
    
def setWhiteBackground(img):
    for i in range(img.shape[0]):
        for j in range(img.shape[1]):
            if img[i,j,0]>0.1:
                img[i,j,:]=0
    return img
                
def getLabel(box):
    l=b.label.cdata
    if l=="fireextinguisher":
        return 1
    if l=="exit":
        return 2
    return 0

# %%
images=[]
labels=[]
scale=4
reduction=8
classes=3 # exit, fireextinguisher, none
for i in obj.dataset.images.image[:]:
    imgfile=os.path.join(basepath,i['file'])
    img=cv2.imread(imgfile)
    img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    # resize and 
    # normalize very important!!
    img=cv2.resize(img, (img.shape[1]//scale, img.shape[0]//scale))/255.0
    #print(i['file'],'\t',img.shape)
    height_i=img.shape[0]
    width_i =img.shape[1]
    height_o=height_i//reduction
    width_o =width_i //reduction
    y=np.zeros((height_o,width_o,classes))
    fillRecSoftMax(y,-1,-1,width_o+1,height_o+1,0)
    for b in i.box:
        top   =int(b['top'   ])//scale//reduction
        left  =int(b['left'  ])//scale//reduction
        width =int(b['width' ])//scale//reduction
        height=int(b['height'])//scale//reduction
        label=getLabel(b)
        
        #setCenter(y,top,left,width,height)
        fillRecSoftMax(y,left,top,width,height,label)
        #print("  ",b.label.cdata,"\t->\t[",top,",",left,",",width,",",height,"]")
    images.append(img)
    labels.append(y)

# %%
images_np=np.array(images)
y_train=np.array(labels[:-100])
y_test =np.array(labels[:100])
print(images_np.shape)
x_train=images_np[:-100]
x_test =images_np[:100]
print(x_train[idx].shape)
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
print(np.min(y_train),np.max(y_train))
for i in range(10):
    idx=random.randint(0,y_train.shape[0])

    plt.figure()
    plt.imshow(x_train[idx].reshape(height_i,width_i,3))
    #plt.show()
    img_np=y_train[idx].reshape(height_o,width_o,3)
    img=cv2.resize(img_np,(width_i,height_i))
    setWhiteBackground(img)
    #plt.imshow(img,cmap='cool',alpha=0.25)
    plt.imshow(img,alpha=0.5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-10-d668c186e6b1> in <module>()
# ----> 1 images_np=np.array(images)
#       2 y_train=np.array(labels[:-100])
#       3 y_test =np.array(labels[:100])
#       4 print(images_np.shape)
#       5 x_train=images_np[:-100]
#
# MemoryError:

# %%
# keras 1.2.2
import keras
import tensorflow as tf
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout,Flatten, LeakyReLU
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization, Activation
from keras.optimizers import RMSprop, Adam
from keras.utils.np_utils import to_categorical

# %%
#input_shape=(360,640,3)
# Dynamic Imput size
input_shape=(None,None,3)
model = Sequential()

# Without BatchNormalization the model doesn't seem to learn
# (11/04/2019) actually I hadn't normalized the color images just I had to divide by 255
# (11/04/2019) with dropouts and without BatchNorm learn but slowly
model.add(Conv2D(32, 5,5,border_mode='same',input_shape=input_shape))
model.add(BatchNormalization())
model.add(LeakyReLU())
model.add(MaxPooling2D(pool_size=(2, 2)))
#model.add(Dropout(0.5))

model.add(Conv2D(32, 3, 3,border_mode='same'))
model.add(BatchNormalization())
model.add(LeakyReLU())
model.add(MaxPooling2D(pool_size=(2, 2)))
#model.add(Dropout(0.5))

model.add(Conv2D(32, 3, 3,border_mode='same'))
model.add(BatchNormalization())
model.add(LeakyReLU())
model.add(MaxPooling2D(pool_size=(2, 2)))
#model.add(Dropout(0.5))

# receptive field aproximation 8(reduction)x3(convolution size)=24
#model.add(Conv2D(1, 3, 3, activation='sigmoid',border_mode='same'))
# receptive field aproximation 8(reduction)x5(convolution size)=40
model.add(Conv2D(32, 3, 3,border_mode='same'))
model.add(BatchNormalization())
model.add(LeakyReLU())

# Last layer n filters = n outputs
model.add(Conv2D(classes, 1, 1, activation='sigmoid',border_mode='same'))

model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# convolution2d_26 (Convolution2D) (None, None, None, 32 2432        convolution2d_input_6[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_21 (BatchNorm (None, None, None, 32 128         convolution2d_26[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_21 (LeakyReLU)         (None, None, None, 32 0           batchnormalization_21[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_16 (MaxPooling2D)   (None, None, None, 32 0           leakyrelu_21[0][0]
# ____________________________________________________________________________________________________
# convolution2d_27 (Convolution2D) (None, None, None, 32 9248        maxpooling2d_16[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_22 (BatchNorm (None, None, None, 32 128         convolution2d_27[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_22 (LeakyReLU)         (None, None, None, 32 0           batchnormalization_22[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_17 (MaxPooling2D)   (None, None, None, 32 0           leakyrelu_22[0][0]
# ____________________________________________________________________________________________________
# convolution2d_28 (Convolution2D) (None, None, None, 32 9248        maxpooling2d_17[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_23 (BatchNorm (None, None, None, 32 128         convolution2d_28[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_23 (LeakyReLU)         (None, None, None, 32 0           batchnormalization_23[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_18 (MaxPooling2D)   (None, None, None, 32 0           leakyrelu_23[0][0]
# ____________________________________________________________________________________________________
# convolution2d_29 (Convolution2D) (None, None, None, 32 9248        maxpooling2d_18[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_24 (BatchNorm (None, None, None, 32 128         convolution2d_29[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_24 (LeakyReLU)         (None, None, None, 32 0           batchnormalization_24[0][0]
# ____________________________________________________________________________________________________
# convolution2d_30 (Convolution2D) (None, None, None, 3) 99          leakyrelu_24[0][0]
# ====================================================================================================
# Total params: 30,787
# Trainable params: 30,531
# Non-trainable params: 256
# ____________________________________________________________________________________________________

# %%
model.compile(loss='binary_crossentropy',
              optimizer=Adam(),
              metrics=['accuracy'])

# %%
batch_size=100
epochs=250
history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    nb_epoch=epochs,
                    validation_data=[x_test,y_test],
                    verbose=1)
# Out:
# Train on 986 samples, validate on 100 samples
# Epoch 1/250
# 986/986 [==============================] - 10s - loss: 0.6096 - acc: 0.7096 - val_loss: 0.6187 - val_acc: 0.6685
# Epoch 2/250
# 986/986 [==============================] - 6s - loss: 0.5048 - acc: 0.8620 - val_loss: 0.5218 - val_acc: 0.9664
# Epoch 3/250
# 986/986 [==============================] - 6s - loss: 0.4404 - acc: 0.9346 - val_loss: 0.4916 - val_acc: 0.9771
# Epoch 4/250
# 986/986 [==============================] - 7s - loss: 0.3909 - acc: 0.9588 - val_loss: 0.4656 - val_acc: 0.9771
# Epoch 5/250
# 986/986 [==============================] - 6s - loss: 0.3494 - acc: 0.9698 - val_loss: 0.4331 - val_acc: 0.9771
# Epoch 6/250
# 986/986 [==============================] - 7s - loss: 0.3131 - acc: 0.9759 - val_loss: 0.4213 - val_acc: 0.9771
# Epoch 7/250
# 986/986 [==============================] - 7s - loss: 0.2813 - acc: 0.9784 - val_loss: 0.4026 - val_acc: 0.9771
# Epoch 8/250
# 986/986 [==============================] - 7s - loss: 0.2533 - acc: 0.9802 - val_loss: 0.3717 - val_acc: 0.9772
# Epoch 9/250
# 986/986 [==============================] - 6s - loss: 0.2289 - acc: 0.9816 - val_loss: 0.3436 - val_acc: 0.9772
# Epoch 10/250
# 986/986 [==============================] - 6s - loss: 0.2072 - acc: 0.9827 - val_loss: 0.3008 - val_acc: 0.9772
# Epoch 11/250
# 986/986 [==============================] - 7s - loss: 0.1884 - acc: 0.9836 - val_loss: 0.2747 - val_acc: 0.9772
# Epoch 12/250
# 986/986 [==============================] - 6s - loss: 0.1717 - acc: 0.9847 - val_loss: 0.2342 - val_acc: 0.9772
# Epoch 13/250
# 986/986 [==============================] - 6s - loss: 0.1567 - acc: 0.9852 - val_loss: 0.2269 - val_acc: 0.9772
# Epoch 14/250
# 986/986 [==============================] - 7s - loss: 0.1435 - acc: 0.9861 - val_loss: 0.2009 - val_acc: 0.9772
# Epoch 15/250
# 986/986 [==============================] - 7s - loss: 0.1324 - acc: 0.9864 - val_loss: 0.1840 - val_acc: 0.9772
# Epoch 16/250
# 986/986 [==============================] - 6s - loss: 0.1222 - acc: 0.9869 - val_loss: 0.1614 - val_acc: 0.9772
# Epoch 17/250
# 986/986 [==============================] - 7s - loss: 0.1130 - acc: 0.9871 - val_loss: 0.1613 - val_acc: 0.9772
# Epoch 18/250
# 986/986 [==============================] - 6s - loss: 0.1046 - acc: 0.9875 - val_loss: 0.1527 - val_acc: 0.9772
# Epoch 19/250
# 986/986 [==============================] - 7s - loss: 0.0976 - acc: 0.9877 - val_loss: 0.1401 - val_acc: 0.9772
# Epoch 20/250
# 986/986 [==============================] - 7s - loss: 0.0915 - acc: 0.9881 - val_loss: 0.1316 - val_acc: 0.9772
# Epoch 21/250
# 986/986 [==============================] - 7s - loss: 0.0859 - acc: 0.9882 - val_loss: 0.1207 - val_acc: 0.9776
# Epoch 22/250
# 986/986 [==============================] - 7s - loss: 0.0808 - acc: 0.9884 - val_loss: 0.1156 - val_acc: 0.9782
# Epoch 23/250
# 986/986 [==============================] - 7s - loss: 0.0760 - acc: 0.9890 - val_loss: 0.1144 - val_acc: 0.9788
# Epoch 24/250
# 986/986 [==============================] - 7s - loss: 0.0716 - acc: 0.9893 - val_loss: 0.1132 - val_acc: 0.9799
# Epoch 25/250
# 986/986 [==============================] - 7s - loss: 0.0678 - acc: 0.9894 - val_loss: 0.1174 - val_acc: 0.9792
# Epoch 26/250
# 986/986 [==============================] - 7s - loss: 0.0655 - acc: 0.9893 - val_loss: 0.1040 - val_acc: 0.9808
# Epoch 27/250
# 986/986 [==============================] - 7s - loss: 0.0624 - acc: 0.9895 - val_loss: 0.0976 - val_acc: 0.9812
# Epoch 28/250
# 986/986 [==============================] - 7s - loss: 0.0603 - acc: 0.9892 - val_loss: 0.0970 - val_acc: 0.9828
# Epoch 29/250
# 986/986 [==============================] - 7s - loss: 0.0565 - acc: 0.9900 - val_loss: 0.1077 - val_acc: 0.9828
# Epoch 30/250
# 986/986 [==============================] - 6s - loss: 0.0536 - acc: 0.9903 - val_loss: 0.1171 - val_acc: 0.9827
# Epoch 31/250
# 986/986 [==============================] - 6s - loss: 0.0515 - acc: 0.9905 - val_loss: 0.1228 - val_acc: 0.9840
# Epoch 32/250
# 986/986 [==============================] - 7s - loss: 0.0503 - acc: 0.9902 - val_loss: 0.0957 - val_acc: 0.9822
# Epoch 33/250
# 986/986 [==============================] - 7s - loss: 0.0483 - acc: 0.9905 - val_loss: 0.0919 - val_acc: 0.9842
# Epoch 34/250
# 986/986 [==============================] - 7s - loss: 0.0462 - acc: 0.9908 - val_loss: 0.0858 - val_acc: 0.9835
# Epoch 35/250
# 986/986 [==============================] - 7s - loss: 0.0445 - acc: 0.9910 - val_loss: 0.0995 - val_acc: 0.9842
# Epoch 36/250
# 986/986 [==============================] - 7s - loss: 0.0439 - acc: 0.9907 - val_loss: 0.0954 - val_acc: 0.9852
# Epoch 37/250
# 986/986 [==============================] - 7s - loss: 0.0426 - acc: 0.9910 - val_loss: 0.0904 - val_acc: 0.9855
# Epoch 38/250
# 986/986 [==============================] - 7s - loss: 0.0413 - acc: 0.9910 - val_loss: 0.1364 - val_acc: 0.9878
# Epoch 39/250
# 986/986 [==============================] - 7s - loss: 0.0399 - acc: 0.9912 - val_loss: 0.0912 - val_acc: 0.9882
# Epoch 40/250
# 986/986 [==============================] - 7s - loss: 0.0387 - acc: 0.9914 - val_loss: 0.0934 - val_acc: 0.9895
# Epoch 41/250
# 986/986 [==============================] - 7s - loss: 0.0378 - acc: 0.9914 - val_loss: 0.1013 - val_acc: 0.9898
# Epoch 42/250
# 986/986 [==============================] - 7s - loss: 0.0374 - acc: 0.9914 - val_loss: 0.1489 - val_acc: 0.9838
# Epoch 43/250
# 986/986 [==============================] - 8s - loss: 0.0363 - acc: 0.9915 - val_loss: 0.1497 - val_acc: 0.9833
# Epoch 44/250
# 986/986 [==============================] - 7s - loss: 0.0370 - acc: 0.9909 - val_loss: 0.0705 - val_acc: 0.9908
# Epoch 45/250
# 986/986 [==============================] - 7s - loss: 0.0350 - acc: 0.9916 - val_loss: 0.0827 - val_acc: 0.9916
# Epoch 46/250
# 986/986 [==============================] - 7s - loss: 0.0337 - acc: 0.9919 - val_loss: 0.1403 - val_acc: 0.9832
# Epoch 47/250
# 986/986 [==============================] - 7s - loss: 0.0328 - acc: 0.9920 - val_loss: 0.0884 - val_acc: 0.9909
# Epoch 48/250
# 986/986 [==============================] - 7s - loss: 0.0321 - acc: 0.9921 - val_loss: 0.0635 - val_acc: 0.9933
# Epoch 49/250
# 986/986 [==============================] - 7s - loss: 0.0323 - acc: 0.9917 - val_loss: 0.0693 - val_acc: 0.9923
# Epoch 50/250
# 986/986 [==============================] - 7s - loss: 0.0314 - acc: 0.9919 - val_loss: 0.0961 - val_acc: 0.9898
# Epoch 51/250
# 986/986 [==============================] - 7s - loss: 0.0312 - acc: 0.9921 - val_loss: 0.0973 - val_acc: 0.9879
# Epoch 52/250
# 986/986 [==============================] - 7s - loss: 0.0308 - acc: 0.9920 - val_loss: 0.1290 - val_acc: 0.9829
# Epoch 53/250
# 986/986 [==============================] - 7s - loss: 0.0304 - acc: 0.9920 - val_loss: 0.0873 - val_acc: 0.9911
# Epoch 54/250
# 986/986 [==============================] - 7s - loss: 0.0298 - acc: 0.9920 - val_loss: 0.2250 - val_acc: 0.9040
# Epoch 55/250
# 986/986 [==============================] - 7s - loss: 0.0288 - acc: 0.9923 - val_loss: 0.1775 - val_acc: 0.9629
# Epoch 56/250
# 986/986 [==============================] - 7s - loss: 0.0285 - acc: 0.9924 - val_loss: 0.0551 - val_acc: 0.9927
# Epoch 57/250
# 986/986 [==============================] - 7s - loss: 0.0291 - acc: 0.9919 - val_loss: 0.0271 - val_acc: 0.9937
# Epoch 58/250
# 986/986 [==============================] - 7s - loss: 0.0279 - acc: 0.9922 - val_loss: 0.1324 - val_acc: 0.9799
# Epoch 59/250
# 986/986 [==============================] - 7s - loss: 0.0270 - acc: 0.9927 - val_loss: 0.3186 - val_acc: 0.8645
# Epoch 60/250
# 986/986 [==============================] - 7s - loss: 0.0268 - acc: 0.9927 - val_loss: 0.0589 - val_acc: 0.9932
# Epoch 61/250
# 986/986 [==============================] - 7s - loss: 0.0266 - acc: 0.9925 - val_loss: 0.0824 - val_acc: 0.9892
# Epoch 62/250
# 986/986 [==============================] - 7s - loss: 0.0258 - acc: 0.9929 - val_loss: 0.1567 - val_acc: 0.9605
# Epoch 63/250
# 986/986 [==============================] - 7s - loss: 0.0250 - acc: 0.9931 - val_loss: 0.0993 - val_acc: 0.9866
# Epoch 64/250
# 986/986 [==============================] - 7s - loss: 0.0254 - acc: 0.9927 - val_loss: 0.1397 - val_acc: 0.9763
# Epoch 65/250
# 986/986 [==============================] - 7s - loss: 0.0247 - acc: 0.9930 - val_loss: 0.0640 - val_acc: 0.9929
# Epoch 66/250
# 986/986 [==============================] - 7s - loss: 0.0240 - acc: 0.9932 - val_loss: 0.0950 - val_acc: 0.9886
# Epoch 67/250
# 986/986 [==============================] - 7s - loss: 0.0240 - acc: 0.9931 - val_loss: 0.0981 - val_acc: 0.9863
# Epoch 68/250
# 986/986 [==============================] - 7s - loss: 0.0239 - acc: 0.9930 - val_loss: 0.0699 - val_acc: 0.9914
# Epoch 69/250
# 986/986 [==============================] - 7s - loss: 0.0234 - acc: 0.9933 - val_loss: 0.0594 - val_acc: 0.9912
# Epoch 70/250
# 986/986 [==============================] - 7s - loss: 0.0235 - acc: 0.9932 - val_loss: 0.0574 - val_acc: 0.9919
# Epoch 71/250
# 986/986 [==============================] - 7s - loss: 0.0227 - acc: 0.9934 - val_loss: 0.1445 - val_acc: 0.9708
# Epoch 72/250
# 986/986 [==============================] - 7s - loss: 0.0227 - acc: 0.9933 - val_loss: 0.0341 - val_acc: 0.9945
# Epoch 73/250
# 986/986 [==============================] - 7s - loss: 0.0225 - acc: 0.9933 - val_loss: 0.0652 - val_acc: 0.9914
# Epoch 74/250
# 986/986 [==============================] - 7s - loss: 0.0221 - acc: 0.9935 - val_loss: 0.0352 - val_acc: 0.9951
# Epoch 75/250
# 986/986 [==============================] - 7s - loss: 0.0219 - acc: 0.9935 - val_loss: 0.0468 - val_acc: 0.9936
# Epoch 76/250
# 986/986 [==============================] - 7s - loss: 0.0217 - acc: 0.9935 - val_loss: 0.0249 - val_acc: 0.9941
# Epoch 77/250
# 986/986 [==============================] - 7s - loss: 0.0212 - acc: 0.9937 - val_loss: 0.0278 - val_acc: 0.9934
# Epoch 78/250
# 986/986 [==============================] - 7s - loss: 0.0211 - acc: 0.9937 - val_loss: 0.0243 - val_acc: 0.9940
# Epoch 79/250
# 986/986 [==============================] - 7s - loss: 0.0219 - acc: 0.9933 - val_loss: 0.0263 - val_acc: 0.9938
# Epoch 80/250
# 986/986 [==============================] - 7s - loss: 0.0213 - acc: 0.9935 - val_loss: 0.0474 - val_acc: 0.9918
# Epoch 81/250
# 986/986 [==============================] - 7s - loss: 0.0214 - acc: 0.9935 - val_loss: 0.0296 - val_acc: 0.9944
# Epoch 82/250
# 986/986 [==============================] - 7s - loss: 0.0210 - acc: 0.9936 - val_loss: 0.3394 - val_acc: 0.8307
# Epoch 83/250
# 986/986 [==============================] - 7s - loss: 0.0205 - acc: 0.9937 - val_loss: 0.0283 - val_acc: 0.9939
# Epoch 84/250
# 986/986 [==============================] - 7s - loss: 0.0199 - acc: 0.9940 - val_loss: 0.0268 - val_acc: 0.9941
# Epoch 85/250
# 986/986 [==============================] - 7s - loss: 0.0204 - acc: 0.9937 - val_loss: 0.0197 - val_acc: 0.9951
# Epoch 86/250
# 986/986 [==============================] - 7s - loss: 0.0198 - acc: 0.9941 - val_loss: 0.1234 - val_acc: 0.9665
# Epoch 87/250
# 986/986 [==============================] - 7s - loss: 0.0192 - acc: 0.9941 - val_loss: 0.0251 - val_acc: 0.9946
# Epoch 88/250
# 986/986 [==============================] - 7s - loss: 0.0191 - acc: 0.9942 - val_loss: 0.0168 - val_acc: 0.9952
# Epoch 89/250
# 986/986 [==============================] - 7s - loss: 0.0198 - acc: 0.9938 - val_loss: 0.0680 - val_acc: 0.9857
# Epoch 90/250
# 986/986 [==============================] - 7s - loss: 0.0201 - acc: 0.9935 - val_loss: 0.0189 - val_acc: 0.9946
# Epoch 91/250
# 986/986 [==============================] - 7s - loss: 0.0196 - acc: 0.9937 - val_loss: 0.0604 - val_acc: 0.9880
# Epoch 92/250
# 986/986 [==============================] - 7s - loss: 0.0198 - acc: 0.9938 - val_loss: 0.0667 - val_acc: 0.9857
# Epoch 93/250
# 986/986 [==============================] - 8s - loss: 0.0196 - acc: 0.9937 - val_loss: 0.0575 - val_acc: 0.9896
# Epoch 94/250
# 986/986 [==============================] - 7s - loss: 0.0192 - acc: 0.9938 - val_loss: 0.0384 - val_acc: 0.9936
# Epoch 95/250
# 986/986 [==============================] - 7s - loss: 0.0189 - acc: 0.9942 - val_loss: 0.0179 - val_acc: 0.9954
# Epoch 96/250
# 986/986 [==============================] - 7s - loss: 0.0192 - acc: 0.9938 - val_loss: 0.0277 - val_acc: 0.9933
# Epoch 97/250
# 986/986 [==============================] - 7s - loss: 0.0185 - acc: 0.9941 - val_loss: 0.0251 - val_acc: 0.9944
# Epoch 98/250
# 986/986 [==============================] - 7s - loss: 0.0180 - acc: 0.9943 - val_loss: 0.0201 - val_acc: 0.9953
# Epoch 99/250
# 986/986 [==============================] - 7s - loss: 0.0183 - acc: 0.9941 - val_loss: 0.0390 - val_acc: 0.9918
# Epoch 100/250
# 986/986 [==============================] - 7s - loss: 0.0183 - acc: 0.9942 - val_loss: 0.0332 - val_acc: 0.9928
# Epoch 101/250
# 986/986 [==============================] - 7s - loss: 0.0183 - acc: 0.9941 - val_loss: 0.0435 - val_acc: 0.9911
# Epoch 102/250
# 986/986 [==============================] - 7s - loss: 0.0189 - acc: 0.9940 - val_loss: 0.0198 - val_acc: 0.9929
# Epoch 103/250
# 986/986 [==============================] - 7s - loss: 0.0184 - acc: 0.9941 - val_loss: 0.0225 - val_acc: 0.9940
# Epoch 104/250
# 986/986 [==============================] - 7s - loss: 0.0180 - acc: 0.9941 - val_loss: 0.0223 - val_acc: 0.9942
# Epoch 105/250
# 986/986 [==============================] - 7s - loss: 0.0190 - acc: 0.9939 - val_loss: 0.0196 - val_acc: 0.9946
# Epoch 106/250
# 986/986 [==============================] - 7s - loss: 0.0186 - acc: 0.9939 - val_loss: 0.0267 - val_acc: 0.9933
# Epoch 107/250
# 986/986 [==============================] - 7s - loss: 0.0185 - acc: 0.9940 - val_loss: 0.0774 - val_acc: 0.9801
# Epoch 108/250
# 986/986 [==============================] - 7s - loss: 0.0176 - acc: 0.9943 - val_loss: 0.0188 - val_acc: 0.9935
# Epoch 109/250
# 986/986 [==============================] - 7s - loss: 0.0171 - acc: 0.9945 - val_loss: 0.0186 - val_acc: 0.9938
# Epoch 110/250
# 986/986 [==============================] - 7s - loss: 0.0174 - acc: 0.9943 - val_loss: 0.0215 - val_acc: 0.9951
# Epoch 111/250
# 986/986 [==============================] - 7s - loss: 0.0172 - acc: 0.9944 - val_loss: 0.0160 - val_acc: 0.9946
# Epoch 112/250
# 986/986 [==============================] - 7s - loss: 0.0169 - acc: 0.9945 - val_loss: 0.0162 - val_acc: 0.9959
# Epoch 113/250
# 986/986 [==============================] - 7s - loss: 0.0165 - acc: 0.9946 - val_loss: 0.0166 - val_acc: 0.9959
# Epoch 114/250
# 986/986 [==============================] - 7s - loss: 0.0162 - acc: 0.9948 - val_loss: 0.0147 - val_acc: 0.9953
# Epoch 115/250
# 986/986 [==============================] - 7s - loss: 0.0158 - acc: 0.9948 - val_loss: 0.0178 - val_acc: 0.9952
# Epoch 116/250
# 986/986 [==============================] - 7s - loss: 0.0157 - acc: 0.9949 - val_loss: 0.0206 - val_acc: 0.9946
# Epoch 117/250
# 986/986 [==============================] - 7s - loss: 0.0155 - acc: 0.9950 - val_loss: 0.0229 - val_acc: 0.9942
# Epoch 118/250
# 986/986 [==============================] - 7s - loss: 0.0167 - acc: 0.9943 - val_loss: 0.0161 - val_acc: 0.9955
# Epoch 119/250
# 986/986 [==============================] - 7s - loss: 0.0169 - acc: 0.9944 - val_loss: 0.0413 - val_acc: 0.9887
# Epoch 120/250
# 986/986 [==============================] - 7s - loss: 0.0163 - acc: 0.9945 - val_loss: 0.0203 - val_acc: 0.9953
# Epoch 121/250
# 986/986 [==============================] - 7s - loss: 0.0154 - acc: 0.9949 - val_loss: 0.0141 - val_acc: 0.9954
# Epoch 122/250
# 986/986 [==============================] - 7s - loss: 0.0152 - acc: 0.9951 - val_loss: 0.0177 - val_acc: 0.9954
# Epoch 123/250
# 986/986 [==============================] - 7s - loss: 0.0155 - acc: 0.9948 - val_loss: 0.0136 - val_acc: 0.9955
# Epoch 124/250
# 986/986 [==============================] - 7s - loss: 0.0168 - acc: 0.9943 - val_loss: 0.0149 - val_acc: 0.9951
# Epoch 125/250
# 986/986 [==============================] - 7s - loss: 0.0158 - acc: 0.9947 - val_loss: 0.0574 - val_acc: 0.9849
# Epoch 126/250
# 986/986 [==============================] - 7s - loss: 0.0152 - acc: 0.9950 - val_loss: 0.0171 - val_acc: 0.9958
# Epoch 127/250
# 986/986 [==============================] - 7s - loss: 0.0148 - acc: 0.9951 - val_loss: 0.0166 - val_acc: 0.9946
# Epoch 128/250
# 986/986 [==============================] - 7s - loss: 0.0147 - acc: 0.9952 - val_loss: 0.0193 - val_acc: 0.9935
# Epoch 129/250
# 986/986 [==============================] - 7s - loss: 0.0148 - acc: 0.9951 - val_loss: 0.1580 - val_acc: 0.9367
# Epoch 130/250
# 986/986 [==============================] - 7s - loss: 0.0153 - acc: 0.9950 - val_loss: 0.0148 - val_acc: 0.9955
# Epoch 131/250
# 986/986 [==============================] - 7s - loss: 0.0145 - acc: 0.9952 - val_loss: 0.0137 - val_acc: 0.9955
# Epoch 132/250
# 986/986 [==============================] - 7s - loss: 0.0139 - acc: 0.9954 - val_loss: 0.0165 - val_acc: 0.9956
# Epoch 133/250
# 986/986 [==============================] - 7s - loss: 0.0140 - acc: 0.9953 - val_loss: 0.0137 - val_acc: 0.9957
# Epoch 134/250
# 986/986 [==============================] - 7s - loss: 0.0146 - acc: 0.9952 - val_loss: 0.0146 - val_acc: 0.9952
# Epoch 135/250
# 986/986 [==============================] - 7s - loss: 0.0150 - acc: 0.9950 - val_loss: 0.0521 - val_acc: 0.9864
# Epoch 136/250
# 986/986 [==============================] - 7s - loss: 0.0152 - acc: 0.9949 - val_loss: 0.0162 - val_acc: 0.9944
# Epoch 137/250
# 986/986 [==============================] - 7s - loss: 0.0144 - acc: 0.9952 - val_loss: 0.0130 - val_acc: 0.9959
# Epoch 138/250
# 986/986 [==============================] - 7s - loss: 0.0139 - acc: 0.9954 - val_loss: 0.0192 - val_acc: 0.9948
# Epoch 139/250
# 986/986 [==============================] - 7s - loss: 0.0134 - acc: 0.9956 - val_loss: 0.0128 - val_acc: 0.9962
# Epoch 140/250
# 986/986 [==============================] - 7s - loss: 0.0136 - acc: 0.9955 - val_loss: 0.0160 - val_acc: 0.9944
# Epoch 141/250
# 986/986 [==============================] - 7s - loss: 0.0143 - acc: 0.9952 - val_loss: 0.0180 - val_acc: 0.9947
# Epoch 142/250
# 986/986 [==============================] - 7s - loss: 0.0142 - acc: 0.9952 - val_loss: 0.0266 - val_acc: 0.9942
# Epoch 143/250
# 986/986 [==============================] - 7s - loss: 0.0141 - acc: 0.9953 - val_loss: 0.0160 - val_acc: 0.9947
# Epoch 144/250
# 986/986 [==============================] - 7s - loss: 0.0148 - acc: 0.9950 - val_loss: 0.0199 - val_acc: 0.9929
# Epoch 145/250
# 986/986 [==============================] - 7s - loss: 0.0138 - acc: 0.9953 - val_loss: 0.0270 - val_acc: 0.9953
# Epoch 146/250
# 986/986 [==============================] - 7s - loss: 0.0128 - acc: 0.9958 - val_loss: 0.0161 - val_acc: 0.9953
# Epoch 147/250
# 986/986 [==============================] - 7s - loss: 0.0129 - acc: 0.9957 - val_loss: 0.0163 - val_acc: 0.9941
# Epoch 148/250
# 986/986 [==============================] - 7s - loss: 0.0128 - acc: 0.9957 - val_loss: 0.0137 - val_acc: 0.9965
# Epoch 149/250
# 986/986 [==============================] - 7s - loss: 0.0128 - acc: 0.9957 - val_loss: 0.0154 - val_acc: 0.9953
# Epoch 150/250
# 986/986 [==============================] - 7s - loss: 0.0128 - acc: 0.9957 - val_loss: 0.0204 - val_acc: 0.9928
# Epoch 151/250
# 986/986 [==============================] - 7s - loss: 0.0130 - acc: 0.9956 - val_loss: 0.0200 - val_acc: 0.9946
# Epoch 152/250
# 986/986 [==============================] - 7s - loss: 0.0134 - acc: 0.9954 - val_loss: 0.0235 - val_acc: 0.9923
# Epoch 153/250
# 986/986 [==============================] - 7s - loss: 0.0135 - acc: 0.9955 - val_loss: 0.0205 - val_acc: 0.9938
# Epoch 154/250
# 986/986 [==============================] - 7s - loss: 0.0134 - acc: 0.9954 - val_loss: 0.0121 - val_acc: 0.9960
# Epoch 155/250
# 986/986 [==============================] - 7s - loss: 0.0131 - acc: 0.9955 - val_loss: 0.0161 - val_acc: 0.9952
# Epoch 156/250
# 986/986 [==============================] - 7s - loss: 0.0125 - acc: 0.9957 - val_loss: 0.0120 - val_acc: 0.9966
# Epoch 157/250
# 986/986 [==============================] - 7s - loss: 0.0121 - acc: 0.9959 - val_loss: 0.0120 - val_acc: 0.9959
# Epoch 158/250
# 986/986 [==============================] - 7s - loss: 0.0125 - acc: 0.9957 - val_loss: 0.0227 - val_acc: 0.9922
# Epoch 159/250
# 986/986 [==============================] - 7s - loss: 0.0121 - acc: 0.9959 - val_loss: 0.0120 - val_acc: 0.9960
# Epoch 160/250
# 986/986 [==============================] - 7s - loss: 0.0122 - acc: 0.9959 - val_loss: 0.0131 - val_acc: 0.9954
# Epoch 161/250
# 986/986 [==============================] - 7s - loss: 0.0124 - acc: 0.9958 - val_loss: 0.0141 - val_acc: 0.9949
# Epoch 162/250
# 986/986 [==============================] - 7s - loss: 0.0130 - acc: 0.9956 - val_loss: 0.0176 - val_acc: 0.9940
# Epoch 163/250
# 986/986 [==============================] - 7s - loss: 0.0124 - acc: 0.9957 - val_loss: 0.0141 - val_acc: 0.9957
# Epoch 164/250
# 986/986 [==============================] - 7s - loss: 0.0123 - acc: 0.9959 - val_loss: 0.0652 - val_acc: 0.9839
# Epoch 165/250
# 986/986 [==============================] - 8s - loss: 0.0119 - acc: 0.9960 - val_loss: 0.0104 - val_acc: 0.9966
# Epoch 166/250
# 986/986 [==============================] - 7s - loss: 0.0116 - acc: 0.9961 - val_loss: 0.0135 - val_acc: 0.9961
# Epoch 167/250
# 986/986 [==============================] - 7s - loss: 0.0119 - acc: 0.9959 - val_loss: 0.0128 - val_acc: 0.9956
# Epoch 168/250
# 986/986 [==============================] - 7s - loss: 0.0120 - acc: 0.9959 - val_loss: 0.0112 - val_acc: 0.9964
# Epoch 169/250
# 986/986 [==============================] - 7s - loss: 0.0118 - acc: 0.9959 - val_loss: 0.0125 - val_acc: 0.9959
# Epoch 170/250
# 986/986 [==============================] - 7s - loss: 0.0116 - acc: 0.9961 - val_loss: 0.0206 - val_acc: 0.9947
# Epoch 171/250
# 986/986 [==============================] - 7s - loss: 0.0115 - acc: 0.9962 - val_loss: 0.0116 - val_acc: 0.9965
# Epoch 172/250
# 986/986 [==============================] - 7s - loss: 0.0121 - acc: 0.9958 - val_loss: 0.0158 - val_acc: 0.9956
# Epoch 173/250
# 986/986 [==============================] - 7s - loss: 0.0114 - acc: 0.9961 - val_loss: 0.0139 - val_acc: 0.9956
# Epoch 174/250
# 986/986 [==============================] - 7s - loss: 0.0113 - acc: 0.9962 - val_loss: 0.0135 - val_acc: 0.9954
# Epoch 175/250
# 986/986 [==============================] - 7s - loss: 0.0109 - acc: 0.9963 - val_loss: 0.0122 - val_acc: 0.9957
# Epoch 176/250
# 986/986 [==============================] - 7s - loss: 0.0109 - acc: 0.9963 - val_loss: 0.0119 - val_acc: 0.9960
# Epoch 177/250
# 986/986 [==============================] - 7s - loss: 0.0110 - acc: 0.9963 - val_loss: 0.0103 - val_acc: 0.9969
# Epoch 178/250
# 986/986 [==============================] - 7s - loss: 0.0109 - acc: 0.9963 - val_loss: 0.0143 - val_acc: 0.9949
# Epoch 179/250
# 986/986 [==============================] - 7s - loss: 0.0107 - acc: 0.9963 - val_loss: 0.0166 - val_acc: 0.9939
# Epoch 180/250
# 986/986 [==============================] - 7s - loss: 0.0108 - acc: 0.9964 - val_loss: 0.0136 - val_acc: 0.9952
# Epoch 181/250
# 986/986 [==============================] - 7s - loss: 0.0111 - acc: 0.9962 - val_loss: 0.0160 - val_acc: 0.9945
# Epoch 182/250
# 986/986 [==============================] - 7s - loss: 0.0113 - acc: 0.9961 - val_loss: 0.0114 - val_acc: 0.9960
# Epoch 183/250
# 986/986 [==============================] - 7s - loss: 0.0111 - acc: 0.9962 - val_loss: 0.0126 - val_acc: 0.9957
# Epoch 184/250
# 986/986 [==============================] - 7s - loss: 0.0115 - acc: 0.9960 - val_loss: 0.0115 - val_acc: 0.9961
# Epoch 185/250
# 986/986 [==============================] - 7s - loss: 0.0118 - acc: 0.9959 - val_loss: 0.0164 - val_acc: 0.9948
# Epoch 186/250
# 986/986 [==============================] - 7s - loss: 0.0110 - acc: 0.9962 - val_loss: 0.0193 - val_acc: 0.9930
# Epoch 187/250
# 986/986 [==============================] - 7s - loss: 0.0111 - acc: 0.9962 - val_loss: 0.0107 - val_acc: 0.9967
# Epoch 188/250
# 986/986 [==============================] - 7s - loss: 0.0105 - acc: 0.9965 - val_loss: 0.0108 - val_acc: 0.9961
# Epoch 189/250
# 986/986 [==============================] - 7s - loss: 0.0105 - acc: 0.9963 - val_loss: 0.0109 - val_acc: 0.9960
# Epoch 190/250
# 986/986 [==============================] - 7s - loss: 0.0103 - acc: 0.9965 - val_loss: 0.0127 - val_acc: 0.9956
# Epoch 191/250
# 986/986 [==============================] - 7s - loss: 0.0101 - acc: 0.9966 - val_loss: 0.0105 - val_acc: 0.9965
# Epoch 192/250
# 986/986 [==============================] - 7s - loss: 0.0106 - acc: 0.9963 - val_loss: 0.0117 - val_acc: 0.9959
# Epoch 193/250
# 986/986 [==============================] - 7s - loss: 0.0123 - acc: 0.9955 - val_loss: 0.0198 - val_acc: 0.9933
# Epoch 194/250
# 986/986 [==============================] - 7s - loss: 0.0116 - acc: 0.9960 - val_loss: 0.0131 - val_acc: 0.9953
# Epoch 195/250
# 986/986 [==============================] - 7s - loss: 0.0105 - acc: 0.9964 - val_loss: 0.0125 - val_acc: 0.9959
# Epoch 196/250
# 986/986 [==============================] - 7s - loss: 0.0102 - acc: 0.9965 - val_loss: 0.0094 - val_acc: 0.9969
# Epoch 197/250
# 986/986 [==============================] - 7s - loss: 0.0107 - acc: 0.9963 - val_loss: 0.0139 - val_acc: 0.9950
# Epoch 198/250
# 986/986 [==============================] - 7s - loss: 0.0109 - acc: 0.9961 - val_loss: 0.0156 - val_acc: 0.9943
# Epoch 199/250
# 986/986 [==============================] - 7s - loss: 0.0109 - acc: 0.9962 - val_loss: 0.0168 - val_acc: 0.9941
# Epoch 200/250
# 986/986 [==============================] - 7s - loss: 0.0106 - acc: 0.9962 - val_loss: 0.0104 - val_acc: 0.9965
# Epoch 201/250
# 986/986 [==============================] - 7s - loss: 0.0103 - acc: 0.9965 - val_loss: 0.0114 - val_acc: 0.9966
# Epoch 202/250
# 986/986 [==============================] - 7s - loss: 0.0112 - acc: 0.9961 - val_loss: 0.0172 - val_acc: 0.9938
# Epoch 203/250
# 986/986 [==============================] - 7s - loss: 0.0109 - acc: 0.9962 - val_loss: 0.0143 - val_acc: 0.9948
# Epoch 204/250
# 986/986 [==============================] - 7s - loss: 0.0103 - acc: 0.9964 - val_loss: 0.0111 - val_acc: 0.9961
# Epoch 205/250
# 986/986 [==============================] - 7s - loss: 0.0103 - acc: 0.9964 - val_loss: 0.0110 - val_acc: 0.9958
# Epoch 206/250
# 986/986 [==============================] - 7s - loss: 0.0101 - acc: 0.9966 - val_loss: 0.0105 - val_acc: 0.9967
# Epoch 207/250
# 986/986 [==============================] - 7s - loss: 0.0097 - acc: 0.9966 - val_loss: 0.0113 - val_acc: 0.9966
# Epoch 208/250
# 986/986 [==============================] - 7s - loss: 0.0093 - acc: 0.9968 - val_loss: 0.0081 - val_acc: 0.9974
# Epoch 209/250
# 986/986 [==============================] - 7s - loss: 0.0093 - acc: 0.9969 - val_loss: 0.0086 - val_acc: 0.9969
# Epoch 210/250
# 986/986 [==============================] - 7s - loss: 0.0095 - acc: 0.9968 - val_loss: 0.0232 - val_acc: 0.9925
# Epoch 211/250
# 986/986 [==============================] - 7s - loss: 0.0097 - acc: 0.9967 - val_loss: 0.0102 - val_acc: 0.9964
# Epoch 212/250
# 986/986 [==============================] - 7s - loss: 0.0098 - acc: 0.9966 - val_loss: 0.0131 - val_acc: 0.9951
# Epoch 213/250
# 986/986 [==============================] - 8s - loss: 0.0100 - acc: 0.9965 - val_loss: 0.0153 - val_acc: 0.9949
# Epoch 214/250
# 986/986 [==============================] - 7s - loss: 0.0097 - acc: 0.9966 - val_loss: 0.0111 - val_acc: 0.9964
# Epoch 215/250
# 986/986 [==============================] - 7s - loss: 0.0093 - acc: 0.9968 - val_loss: 0.0102 - val_acc: 0.9964
# Epoch 216/250
# 986/986 [==============================] - 7s - loss: 0.0092 - acc: 0.9968 - val_loss: 0.0153 - val_acc: 0.9945
# Epoch 217/250
# 986/986 [==============================] - 6s - loss: 0.0094 - acc: 0.9968 - val_loss: 0.0124 - val_acc: 0.9952
# Epoch 218/250
# 986/986 [==============================] - 6s - loss: 0.0089 - acc: 0.9970 - val_loss: 0.0114 - val_acc: 0.9957
# Epoch 219/250
# 986/986 [==============================] - 7s - loss: 0.0087 - acc: 0.9971 - val_loss: 0.0112 - val_acc: 0.9958
# Epoch 220/250
# 986/986 [==============================] - 7s - loss: 0.0092 - acc: 0.9968 - val_loss: 0.0118 - val_acc: 0.9960
# Epoch 221/250
# 986/986 [==============================] - 8s - loss: 0.0088 - acc: 0.9970 - val_loss: 0.0081 - val_acc: 0.9974
# Epoch 222/250
# 986/986 [==============================] - 7s - loss: 0.0086 - acc: 0.9971 - val_loss: 0.0117 - val_acc: 0.9962
# Epoch 223/250
# 986/986 [==============================] - 7s - loss: 0.0098 - acc: 0.9965 - val_loss: 0.0144 - val_acc: 0.9946
# Epoch 224/250
# 986/986 [==============================] - 7s - loss: 0.0093 - acc: 0.9969 - val_loss: 0.0098 - val_acc: 0.9967
# Epoch 225/250
# 986/986 [==============================] - 7s - loss: 0.0088 - acc: 0.9970 - val_loss: 0.0080 - val_acc: 0.9972
# Epoch 226/250
# 986/986 [==============================] - 7s - loss: 0.0089 - acc: 0.9969 - val_loss: 0.0155 - val_acc: 0.9947
# Epoch 227/250
# 986/986 [==============================] - 7s - loss: 0.0092 - acc: 0.9969 - val_loss: 0.0104 - val_acc: 0.9966
# Epoch 228/250
# 986/986 [==============================] - 7s - loss: 0.0087 - acc: 0.9970 - val_loss: 0.0134 - val_acc: 0.9959
# Epoch 229/250
# 986/986 [==============================] - 7s - loss: 0.0089 - acc: 0.9969 - val_loss: 0.0100 - val_acc: 0.9963
# Epoch 230/250
# 986/986 [==============================] - 7s - loss: 0.0084 - acc: 0.9971 - val_loss: 0.0134 - val_acc: 0.9950
# Epoch 231/250
# 986/986 [==============================] - 7s - loss: 0.0084 - acc: 0.9971 - val_loss: 0.0113 - val_acc: 0.9954
# Epoch 232/250
# 986/986 [==============================] - 7s - loss: 0.0084 - acc: 0.9971 - val_loss: 0.0103 - val_acc: 0.9971
# Epoch 233/250
# 986/986 [==============================] - 7s - loss: 0.0087 - acc: 0.9970 - val_loss: 0.0092 - val_acc: 0.9964
# Epoch 234/250
# 986/986 [==============================] - 7s - loss: 0.0089 - acc: 0.9969 - val_loss: 0.0127 - val_acc: 0.9951
# Epoch 235/250
# 986/986 [==============================] - 7s - loss: 0.0087 - acc: 0.9970 - val_loss: 0.0104 - val_acc: 0.9962
# Epoch 236/250
# 986/986 [==============================] - 7s - loss: 0.0091 - acc: 0.9969 - val_loss: 0.0170 - val_acc: 0.9947
# Epoch 237/250
# 986/986 [==============================] - 7s - loss: 0.0083 - acc: 0.9971 - val_loss: 0.0102 - val_acc: 0.9970
# Epoch 238/250
# 986/986 [==============================] - 7s - loss: 0.0085 - acc: 0.9971 - val_loss: 0.0133 - val_acc: 0.9956
# Epoch 239/250
# 986/986 [==============================] - 7s - loss: 0.0091 - acc: 0.9969 - val_loss: 0.0085 - val_acc: 0.9970
# Epoch 240/250
# 986/986 [==============================] - 7s - loss: 0.0088 - acc: 0.9969 - val_loss: 0.0604 - val_acc: 0.9822
# Epoch 241/250
# 986/986 [==============================] - 7s - loss: 0.0092 - acc: 0.9967 - val_loss: 0.0146 - val_acc: 0.9952
# Epoch 242/250
# 986/986 [==============================] - 7s - loss: 0.0090 - acc: 0.9968 - val_loss: 0.0092 - val_acc: 0.9971
# Epoch 243/250
# 986/986 [==============================] - 7s - loss: 0.0084 - acc: 0.9970 - val_loss: 0.0085 - val_acc: 0.9973
# Epoch 244/250
# 986/986 [==============================] - 7s - loss: 0.0082 - acc: 0.9971 - val_loss: 0.0084 - val_acc: 0.9977
# Epoch 245/250
# 986/986 [==============================] - 7s - loss: 0.0084 - acc: 0.9971 - val_loss: 0.0077 - val_acc: 0.9972
# Epoch 246/250
# 986/986 [==============================] - 7s - loss: 0.0077 - acc: 0.9974 - val_loss: 0.0089 - val_acc: 0.9967
# Epoch 247/250
# 986/986 [==============================] - 7s - loss: 0.0076 - acc: 0.9974 - val_loss: 0.0096 - val_acc: 0.9967
# Epoch 248/250
# 986/986 [==============================] - 7s - loss: 0.0078 - acc: 0.9973 - val_loss: 0.0103 - val_acc: 0.9963
# Epoch 249/250
# 986/986 [==============================] - 7s - loss: 0.0077 - acc: 0.9974 - val_loss: 0.0118 - val_acc: 0.9954
# Epoch 250/250
# 986/986 [==============================] - 7s - loss: 0.0077 - acc: 0.9974 - val_loss: 0.0087 - val_acc: 0.9970

# %%
score = model.evaluate(x_train, y_train, verbose=0)
print('Train loss:', score[0])
print('Train accuracy:', score[1])
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Train loss: 0.00997565973089
# Train accuracy: 0.996416611555
# Test loss: 0.00865077987313
# Test accuracy: 0.997022063732

# %%
plt.figure(1,figsize=(25,50))
y_pred=model.predict(x_train)
y_dif=np.abs(y_pred-y_train)
for i in range(5):
    idx=random.randint(0,x_train.shape[0])
    #print(np.max(y_pred[idx]))
    #print(np.sum(y_dif[idx]/(height_o*width_o)))
    plt.subplot(10, 3, i*3+1)
    plt.imshow(x_train[idx].reshape(height_i,width_i,3))
    #plt.show()
    plt.subplot(10, 3, i*3+2)
    plt.imshow(setWhiteBackground(y_train[idx].reshape(height_o,width_o,3)))
    #plt.show()
    plt.subplot(10, 3, i*3+3)
    plt.imshow(setWhiteBackground(y_pred[idx].reshape(height_o,width_o,3)))
    #plt.show()
    #plt.imshow(y_dif[idx].reshape(height_o,width_o),cmap="gray_r")
plt.show()

# %%
print("TEST")
print(x_test.shape)
plt.figure(1,figsize=(25,50))
y_predf=model.predict(x_test)
y_pred=y_predf>0.5
y_dif=np.abs(y_pred-y_test)
for i in range(5):
    idx=random.randint(0,x_test.shape[0])
    #print(np.max(y_predf[idx]))
    #print(np.sum(y_dif[idx]/(height_o*width_o)))
    plt.subplot(10, 3, i*3+1)
    plt.imshow(x_test[idx].reshape(height_i,width_i,3))
    #plt.show()
    plt.subplot(10, 3, i*3+2)
    plt.imshow(y_test[idx].reshape(height_o,width_o,3))
    #plt.show()
    plt.subplot(10, 3, i*3+3)
    plt.imshow(y_predf[idx].reshape(height_o,width_o,3))
    #plt.show()
    #plt.imshow(y_dif[idx].reshape(height_o,width_o),cmap="gray_r")
    #plt.show()
plt.show()
# Out:
# TEST
# (100, 180, 320, 3)

# %%
idx=random.randint(0,x_test.shape[0])
i=obj.dataset.images.image[idx]
imgfile=os.path.join(basepath,i['file'])
img=cv2.imread(imgfile)
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)/255
plt.figure(1,figsize=(12,24))
for i in range(0,6):
    print(img.shape)
    plt.subplot(6, 2, i*2+1)
    plt.imshow(img)
    y_predf=model.predict(img.reshape(1,img.shape[0],img.shape[1],img.shape[2]))
    print(y_predf.shape)
    plt.subplot(6, 2, i*2+2)
    plt.imshow(y_predf[0].reshape(y_predf.shape[1],y_predf.shape[2],3))
    #img=cv2.pyrDown(img,(0.8,0.8))
    img=cv2.resize(img,(int(img.shape[1]*0.7),int(img.shape[0]*0.7)))
plt.show()
# Out:
# (720, 1280, 3)
# (1, 90, 160, 3)
# (503, 896, 3)
# (1, 62, 112, 3)
# (352, 627, 3)
# (1, 44, 78, 3)
# (246, 438, 3)
# (1, 30, 54, 3)
# (172, 306, 3)
# (1, 21, 38, 3)
# (120, 214, 3)
# (1, 15, 26, 3)

# %%
y_predf=model.predict(img.reshape(1,img.shape[0],img.shape[1],img.shape[2]))
print(y_predf.shape)
# Out:
# (1, 10, 18, 3)

# %%
plt.imshow(y_predf[0].reshape(y_predf.shape[1],y_predf.shape[2],3))
plt.show()
