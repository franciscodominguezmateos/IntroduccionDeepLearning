# %%
# Kernel dl
# Initial code and auxiliar functions. Don't pay attention to this
import os
import random
import numpy as np
import matplotlib.pyplot as plt
import cv2

# Config the matplotlib backend as plotting inline in IPython
# %matplotlib inline

# %%
# pip install untangle
# The easiest way to parse xml files I have found.
import untangle

# %%
# dlib image object detection dataset xml file format
#filename='exit_fire.xml'
basepath='/home/francisco/Pictures/datasets/indoor_object_detection_dataset/faster_bounding_box_dataset/all'
filename='fireextinguisher.xml'
obj=untangle.parse(filename)
len(obj.dataset.images.image)
# Out:
# 818

# %%
def fillRec(img,x,y,w,h):
    for i in range(w):
        for j in range(h):
            img[y+j,x+i,0]=1
images=[]
labels=[]
scale=4
reduction=8
for i in obj.dataset.images.image[:818]:
    imgfile=os.path.join(basepath,i['file'])
    img=cv2.imread(imgfile)
    img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    img=cv2.resize(img, (img.shape[1]//scale, img.shape[0]//scale))
    #print(i['file'],'\t',img.shape)
    height_i=img.shape[0]
    width_i =img.shape[1]
    height_o=height_i//reduction
    width_o =width_i //reduction
    y=np.zeros((height_o,width_o,1))
    for b in i.box:
        top   =int(b['top'])   //scale//reduction
        left  =int(b['left'])  //scale//reduction
        width =int(b['width']) //scale//reduction
        height=int(b['height'])//scale//reduction
        center_x=left+width//2
        center_y=top +height//2
        y[center_y,center_x,0]=1
        #fillRec(y,left,top,width,height)
        #print("  ",b.label.cdata,"\t->\t[",top,",",left,",",width,",",height,"]")
    images.append(img)
    labels.append(y)
plt.figure()
images_np=np.array(images)
y_train=np.array(labels[:718])
y_test =np.array(labels[718:])
print(images_np.shape)
x_train=images_np[:718]
x_test =images_np[718:]
print(x_train[0].shape)
print(y_train.shape)
print(np.min(y_train),np.max(y_train))
plt.imshow(x_train[0].reshape(height_i,width_i,3))
plt.show()
plt.imshow(y_train[0].reshape(height_o,width_o),cmap="gray_r")
plt.show()
# Out:
# (818, 180, 320, 3)
# (180, 320, 3)
# (718, 22, 40, 1)
# 0.0 1.0

# %%
# keras 1.2.2
import keras
import tensorflow as tf
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout,Flatten, LeakyReLU
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization, Activation
from keras.optimizers import RMSprop, Adam
from keras.utils.np_utils import to_categorical

# %%
#input_shape=(360,640,3)
# Dynamic Imput size
input_shape=(None,None,3)
model = Sequential()

# Without BatchNormalization the model doesn't seem to learn
model.add(Conv2D(32, 5,5,border_mode='same',input_shape=input_shape))
model.add(BatchNormalization())
model.add(LeakyReLU())
model.add(MaxPooling2D(pool_size=(2, 2)))
#model.add(Dropout(0.5))

model.add(Conv2D(32, 3, 3,border_mode='same'))
model.add(BatchNormalization())
model.add(LeakyReLU())
model.add(MaxPooling2D(pool_size=(2, 2)))
#model.add(Dropout(0.5))

model.add(Conv2D(32, 3, 3,border_mode='same'))
model.add(BatchNormalization())
model.add(LeakyReLU())
model.add(MaxPooling2D(pool_size=(2, 2)))
#model.add(Dropout(0.5))

model.add(Conv2D(1, 3, 3, activation='sigmoid',border_mode='same'))

model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# convolution2d_74 (Convolution2D) (None, None, None, 32 2432        convolution2d_input_20[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_20 (BatchNorm (None, None, None, 32 128         convolution2d_74[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_13 (LeakyReLU)         (None, None, None, 32 0           batchnormalization_20[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_55 (MaxPooling2D)   (None, None, None, 32 0           leakyrelu_13[0][0]
# ____________________________________________________________________________________________________
# convolution2d_75 (Convolution2D) (None, None, None, 32 9248        maxpooling2d_55[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_21 (BatchNorm (None, None, None, 32 128         convolution2d_75[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_14 (LeakyReLU)         (None, None, None, 32 0           batchnormalization_21[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_56 (MaxPooling2D)   (None, None, None, 32 0           leakyrelu_14[0][0]
# ____________________________________________________________________________________________________
# convolution2d_76 (Convolution2D) (None, None, None, 32 9248        maxpooling2d_56[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_22 (BatchNorm (None, None, None, 32 128         convolution2d_76[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_15 (LeakyReLU)         (None, None, None, 32 0           batchnormalization_22[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_57 (MaxPooling2D)   (None, None, None, 32 0           leakyrelu_15[0][0]
# ____________________________________________________________________________________________________
# convolution2d_77 (Convolution2D) (None, None, None, 1) 289         maxpooling2d_57[0][0]
# ====================================================================================================
# Total params: 21,601
# Trainable params: 21,409
# Non-trainable params: 192
# ____________________________________________________________________________________________________

# %%
model.compile(loss='binary_crossentropy',
              optimizer=Adam(),
              metrics=['accuracy'])

# %%
batch_size=100
epochs=10
history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    nb_epoch=epochs,
                    validation_data=[x_test,y_test],
                    verbose=1)
# Out:
# Train on 718 samples, validate on 100 samples
# Epoch 1/10
# 718/718 [==============================] - 4s - loss: 0.0058 - acc: 0.9983 - val_loss: 0.0095 - val_acc: 0.9986
# Epoch 2/10
# 718/718 [==============================] - 4s - loss: 0.0058 - acc: 0.9982 - val_loss: 0.0067 - val_acc: 0.9986
# Epoch 3/10
# 718/718 [==============================] - 4s - loss: 0.0056 - acc: 0.9983 - val_loss: 0.0069 - val_acc: 0.9986
# Epoch 4/10
# 718/718 [==============================] - 4s - loss: 0.0056 - acc: 0.9983 - val_loss: 0.0058 - val_acc: 0.9987
# Epoch 5/10
# 718/718 [==============================] - 4s - loss: 0.0055 - acc: 0.9983 - val_loss: 0.0074 - val_acc: 0.9986
# Epoch 6/10
# 718/718 [==============================] - 4s - loss: 0.0054 - acc: 0.9984 - val_loss: 0.0066 - val_acc: 0.9986
# Epoch 7/10
# 718/718 [==============================] - 4s - loss: 0.0053 - acc: 0.9984 - val_loss: 0.0079 - val_acc: 0.9986
# Epoch 8/10
# 718/718 [==============================] - 4s - loss: 0.0052 - acc: 0.9984 - val_loss: 0.0052 - val_acc: 0.9987
# Epoch 9/10
# 718/718 [==============================] - 4s - loss: 0.0052 - acc: 0.9984 - val_loss: 0.0062 - val_acc: 0.9986
# Epoch 10/10
# 718/718 [==============================] - 4s - loss: 0.0052 - acc: 0.9984 - val_loss: 0.0052 - val_acc: 0.9986

# %%
score = model.evaluate(x_train, y_train, verbose=0)
print('Train loss:', score[0])
print('Train accuracy:', score[1])
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Train loss: 0.00581216474627
# Train accuracy: 0.998407239369
# Test loss: 0.0051814833656
# Test accuracy: 0.998647165298

# %%
for i in range(5):
    idx=random.randint(0,718)
    y_pred=model.predict(x_train)
    y_dif=np.abs(y_pred-y_train)
    print(np.max(y_pred[idx]))
    print(np.sum(y_dif[idx]/(height_o*width_o)))
    #plt.subplot(10, 3, i*3+1)
    plt.imshow(x_train[idx].reshape(height_i,width_i,3))
    plt.show()
    #plt.subplot(10, 3, i*3+2)
    plt.imshow(y_train[idx].reshape(height_o,width_o),cmap="gray_r")
    plt.show()
    #plt.subplot(10, 3, i*3+3)
    plt.imshow(y_pred[idx].reshape(height_o,width_o),cmap="gray_r")
    plt.show()
    #plt.imshow(y_dif[idx].reshape(height_o,width_o),cmap="gray_r")
    #plt.show()
# Out:
# 0.840819
# 0.00220983584242
# 0.78907
# 0.00620024876956
# 0.340948
# 0.00276693091177
# 0.176394
# 0.00275312453494
# 0.451911
# 0.00509984014641

# %%
print("TEST")
print(x_test.shape)
for i in range(5):
    idx=random.randint(0,x_test.shape[0])
    y_pred=model.predict(x_test)>0.5
    y_dif=np.abs(y_pred-y_test)
    print(np.max(y_pred[idx]))
    print(np.sum(y_dif[idx]/(height_o*width_o)))
    #plt.subplot(10, 3, i*3+1)
    plt.imshow(x_test[idx].reshape(height_i,width_i,3))
    plt.show()
    #plt.subplot(10, 3, i*3+2)
    plt.imshow(y_test[idx].reshape(height_o,width_o),cmap="gray_r")
    plt.show()
    #plt.subplot(10, 3, i*3+3)
    plt.imshow(y_pred[idx].reshape(height_o,width_o),cmap="gray_r")
    plt.show()
    #plt.imshow(y_dif[idx].reshape(height_o,width_o),cmap="gray_r")
    #plt.show()
#plt.show()
# Out:
# TEST
# (100, 180, 320, 3)
# True
# 0.0
# False
# 0.00113636363636
# True
# 0.00227272727273
# True
# 0.00227272727273
# True
# 0.00227272727273
