# %%
# 06/11/2020
# Francisco Dominguez Mateos
# From: https://pytorch.org/tutorials/intermediate/torchvision_tutorial.html

# %%
import os
import numpy as np
import torch
from PIL import Image

import torchvision
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.models.detection.mask_rcnn import MaskRCNNPredictor

#from /referencce folder ?¿
import transforms as T
from engine import train_one_epoch, evaluate
import utils

# %%
print(torch.__version__)
print(torchvision.__version__)
# Out:
# 1.4.0
# 0.5.0

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
class PennFudanDataset(object):
    def __init__(self, root, transforms):
        self.root = root
        self.transforms = transforms
        # load all image files, sorting them to
        # ensure that they are aligned
        self.imgs  = list(sorted(os.listdir(os.path.join(root, "PNGImages"))))
        self.masks = list(sorted(os.listdir(os.path.join(root, "PedMasks"))))

    def __getitem__(self, idx):
        # load images ad masks
        img_path  = os.path.join(self.root, "PNGImages", self.imgs [idx])
        mask_path = os.path.join(self.root, "PedMasks" , self.masks[idx])
        img = Image.open(img_path).convert("RGB")
        # note that we haven't converted the mask to RGB,
        # because each color corresponds to a different instance
        # with 0 being background
        mask = Image.open(mask_path)
        # convert the PIL Image into a numpy array
        mask = np.array(mask)
        # instances are encoded as different colors
        obj_ids = np.unique(mask)
        # first id is the background, so remove it
        obj_ids = obj_ids[1:]

        # split the color-encoded mask into a set
        # of binary masks
        masks = mask == obj_ids[:, None, None]

        # get bounding box coordinates for each mask
        num_objs = len(obj_ids)
        boxes = []
        for i in range(num_objs):
            pos = np.where(masks[i])
            xmin = np.min(pos[1])
            xmax = np.max(pos[1])
            ymin = np.min(pos[0])
            ymax = np.max(pos[0])
            boxes.append([xmin, ymin, xmax, ymax])

        # convert everything into a torch.Tensor
        boxes  = torch.as_tensor(boxes,  dtype=torch.float32)
        # there is only one class
        labels = torch.ones((num_objs,), dtype=torch.int64)
        masks  = torch.as_tensor(masks,  dtype=torch.uint8)

        image_id = torch.tensor([idx])
        area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])
        # suppose all instances are not crowd
        iscrowd = torch.zeros((num_objs,), dtype=torch.int64)

        target = {}
        target["boxes"]    = boxes
        target["labels"]   = labels
        target["masks"]    = masks
        target["image_id"] = image_id
        target["area"]     = area
        target["iscrowd"]  = iscrowd

        if self.transforms is not None:
            img, target = self.transforms(img, target)

        return img, target

    def __len__(self):
        return len(self.imgs)

# %%
def get_model_instance_segmentation(num_classes):
    # load an instance segmentation model pre-trained pre-trained on COCO
    model = torchvision.models.detection.maskrcnn_resnet50_fpn(pretrained=True)

    # get number of input features for the classifier
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    # replace the pre-trained head with a new one
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)

    # now get the number of input features for the mask classifier
    in_features_mask = model.roi_heads.mask_predictor.conv5_mask.in_channels
    hidden_layer = 256
    # and replace the mask predictor with a new one
    model.roi_heads.mask_predictor = MaskRCNNPredictor(in_features_mask,
                                                       hidden_layer,
                                                       num_classes)

    return model

# %%
def get_transform(train):
    transforms = []
    transforms.append(T.ToTensor())
    if train:
        transforms.append(T.RandomHorizontalFlip(0.5))
    return T.Compose(transforms)

# %%
model = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained=True)
dataset = PennFudanDataset('PennFudanPed', get_transform(train=True))
data_loader = torch.utils.data.DataLoader(
 dataset, batch_size=2, shuffle=True, num_workers=4,
 collate_fn=utils.collate_fn)
# For Training
images,targets = next(iter(data_loader))
images = list(image for image in images)
targets = [{k: v for k, v in t.items()} for t in targets]
output = model(images,targets)   # Returns losses and detections
# For inference
model.eval()
x = [torch.rand(3, 300, 400), torch.rand(3, 500, 400)]
predictions = model(x)           # Returns predictions

# %%
def main():
    # train on the GPU or on the CPU, if a GPU is not available
    device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

    # our dataset has two classes only - background and person
    num_classes = 2
    # use our dataset and defined transformations
    dataset      = PennFudanDataset('PennFudanPed', get_transform(train=True))
    dataset_test = PennFudanDataset('PennFudanPed', get_transform(train=False))

    # split the dataset in train and test set
    indices      = torch.randperm(len(dataset)).tolist()
    dataset      = torch.utils.data.Subset(dataset, indices[:-50])
    dataset_test = torch.utils.data.Subset(dataset_test, indices[-50:])

    # define training and validation data loaders
    data_loader = torch.utils.data.DataLoader(
        dataset, batch_size=2, shuffle=True, num_workers=4,
        collate_fn=utils.collate_fn)

    data_loader_test = torch.utils.data.DataLoader(
        dataset_test, batch_size=1, shuffle=False, num_workers=4,
        collate_fn=utils.collate_fn)

    # get the model using our helper function
    model = get_model_instance_segmentation(num_classes)

    # move model to the right device
    model.to(device)

    # construct an optimizer
    params = [p for p in model.parameters() if p.requires_grad]
    optimizer = torch.optim.SGD(params, lr=0.005,
                                momentum=0.9, weight_decay=0.0005)
    # and a learning rate scheduler
    lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                                   step_size=3,
                                                   gamma=0.1)

    # let's train it for 10 epochs
    num_epochs = 10

    for epoch in range(num_epochs):
        # train for one epoch, printing every 10 iterations
        train_one_epoch(model, optimizer, data_loader, device, epoch, print_freq=10)
        # update the learning rate
        lr_scheduler.step()
        # evaluate on the test dataset
        evaluate(model, data_loader_test, device=device)

    print("That's it!")

# %%
main()
# Out:
# Epoch: [0]  [ 0/60]  eta: 0:01:12  lr: 0.000090  loss: 4.8573 (4.8573)  loss_classifier: 1.0598 (1.0598)  loss_box_reg: 0.0862 (0.0862)  loss_mask: 3.6902 (3.6902)  loss_objectness: 0.0195 (0.0195)  loss_rpn_box_reg: 0.0016 (0.0016)  time: 1.2099  data: 0.3780  max mem: 1808
# Epoch: [0]  [10/60]  eta: 0:00:33  lr: 0.000936  loss: 1.6310 (2.6683)  loss_classifier: 0.5298 (0.5675)  loss_box_reg: 0.1464 (0.1706)  loss_mask: 1.1115 (1.8924)  loss_objectness: 0.0216 (0.0254)  loss_rpn_box_reg: 0.0100 (0.0124)  time: 0.6676  data: 0.0390  max mem: 2893
# Epoch: [0]  [20/60]  eta: 0:00:25  lr: 0.001783  loss: 0.8150 (1.6872)  loss_classifier: 0.1799 (0.3566)  loss_box_reg: 0.1288 (0.1387)  loss_mask: 0.4411 (1.1474)  loss_objectness: 0.0250 (0.0312)  loss_rpn_box_reg: 0.0100 (0.0133)  time: 0.6013  data: 0.0047  max mem: 3010
# Epoch: [0]  [30/60]  eta: 0:00:18  lr: 0.002629  loss: 0.4747 (1.2871)  loss_classifier: 0.0863 (0.2658)  loss_box_reg: 0.0966 (0.1223)  loss_mask: 0.2675 (0.8583)  loss_objectness: 0.0206 (0.0264)  loss_rpn_box_reg: 0.0153 (0.0143)  time: 0.5661  data: 0.0044  max mem: 3010
# Epoch: [0]  [40/60]  eta: 0:00:11  lr: 0.003476  loss: 0.4607 (1.0954)  loss_classifier: 0.0763 (0.2245)  loss_box_reg: 0.1025 (0.1272)  loss_mask: 0.2397 (0.7055)  loss_objectness: 0.0130 (0.0220)  loss_rpn_box_reg: 0.0153 (0.0162)  time: 0.5631  data: 0.0045  max mem: 3010
# Epoch: [0]  [50/60]  eta: 0:00:06  lr: 0.004323  loss: 0.5046 (0.9768)  loss_classifier: 0.0862 (0.1975)  loss_box_reg: 0.1387 (0.1334)  loss_mask: 0.2079 (0.6093)  loss_objectness: 0.0067 (0.0192)  loss_rpn_box_reg: 0.0166 (0.0174)  time: 0.6072  data: 0.0046  max mem: 3010
# Epoch: [0]  [59/60]  eta: 0:00:00  lr: 0.005000  loss: 0.4918 (0.8987)  loss_classifier: 0.0768 (0.1790)  loss_box_reg: 0.1627 (0.1333)  loss_mask: 0.2030 (0.5521)  loss_objectness: 0.0041 (0.0170)  loss_rpn_box_reg: 0.0166 (0.0173)  time: 0.6160  data: 0.0045  max mem: 3010
# Epoch: [0] Total time: 0:00:36 (0.6067 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:27  model_time: 0.1680 (0.1680)  evaluator_time: 0.0444 (0.0444)  time: 0.5443  data: 0.3308  max mem: 3010
# Test:  [49/50]  eta: 0:00:00  model_time: 0.1210 (0.1286)  evaluator_time: 0.0102 (0.0167)  time: 0.1473  data: 0.0022  max mem: 3010
# Test: Total time: 0:00:07 (0.1565 s / it)
# Averaged stats: model_time: 0.1210 (0.1286)  evaluator_time: 0.0102 (0.0167)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.578
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.984
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.607
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.576
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.582
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.247
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.650
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.650
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.725
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.643
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.701
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.984
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.888
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.390
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.717
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.296
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.744
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.748
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.675
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.755
# Epoch: [1]  [ 0/60]  eta: 0:00:52  lr: 0.005000  loss: 0.2869 (0.2869)  loss_classifier: 0.0408 (0.0408)  loss_box_reg: 0.0712 (0.0712)  loss_mask: 0.1631 (0.1631)  loss_objectness: 0.0047 (0.0047)  loss_rpn_box_reg: 0.0071 (0.0071)  time: 0.8681  data: 0.3296  max mem: 3010
# Epoch: [1]  [10/60]  eta: 0:00:32  lr: 0.005000  loss: 0.2869 (0.3010)  loss_classifier: 0.0392 (0.0424)  loss_box_reg: 0.0521 (0.0620)  loss_mask: 0.1863 (0.1855)  loss_objectness: 0.0015 (0.0023)  loss_rpn_box_reg: 0.0071 (0.0089)  time: 0.6575  data: 0.0343  max mem: 3010
# Epoch: [1]  [20/60]  eta: 0:00:26  lr: 0.005000  loss: 0.2950 (0.3078)  loss_classifier: 0.0417 (0.0493)  loss_box_reg: 0.0628 (0.0656)  loss_mask: 0.1690 (0.1776)  loss_objectness: 0.0015 (0.0027)  loss_rpn_box_reg: 0.0110 (0.0127)  time: 0.6401  data: 0.0048  max mem: 3010
# Epoch: [1]  [30/60]  eta: 0:00:19  lr: 0.005000  loss: 0.2916 (0.2927)  loss_classifier: 0.0481 (0.0462)  loss_box_reg: 0.0553 (0.0570)  loss_mask: 0.1482 (0.1739)  loss_objectness: 0.0011 (0.0023)  loss_rpn_box_reg: 0.0156 (0.0132)  time: 0.6304  data: 0.0048  max mem: 3010
# Epoch: [1]  [40/60]  eta: 0:00:12  lr: 0.005000  loss: 0.2077 (0.2718)  loss_classifier: 0.0344 (0.0433)  loss_box_reg: 0.0253 (0.0494)  loss_mask: 0.1357 (0.1638)  loss_objectness: 0.0008 (0.0021)  loss_rpn_box_reg: 0.0109 (0.0131)  time: 0.5973  data: 0.0045  max mem: 3010
# Epoch: [1]  [50/60]  eta: 0:00:06  lr: 0.005000  loss: 0.2302 (0.2760)  loss_classifier: 0.0396 (0.0453)  loss_box_reg: 0.0338 (0.0491)  loss_mask: 0.1402 (0.1657)  loss_objectness: 0.0004 (0.0019)  loss_rpn_box_reg: 0.0102 (0.0140)  time: 0.6126  data: 0.0046  max mem: 3010
# Epoch: [1]  [59/60]  eta: 0:00:00  lr: 0.005000  loss: 0.2515 (0.2658)  loss_classifier: 0.0344 (0.0429)  loss_box_reg: 0.0355 (0.0455)  loss_mask: 0.1549 (0.1624)  loss_objectness: 0.0004 (0.0017)  loss_rpn_box_reg: 0.0102 (0.0134)  time: 0.6205  data: 0.0047  max mem: 3010
# Epoch: [1] Total time: 0:00:37 (0.6253 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:23  model_time: 0.1272 (0.1272)  evaluator_time: 0.0157 (0.0157)  time: 0.4787  data: 0.3347  max mem: 3010
# Test:  [49/50]  eta: 0:00:00  model_time: 0.1071 (0.1108)  evaluator_time: 0.0038 (0.0056)  time: 0.1178  data: 0.0024  max mem: 3010
# Test: Total time: 0:00:06 (0.1280 s / it)
# Averaged stats: model_time: 0.1071 (0.1108)  evaluator_time: 0.0038 (0.0056)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.696
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.993
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.869
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.620
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.291
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.753
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.753
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.775
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.751
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.751
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.993
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.927
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.535
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.764
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.304
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.785
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.785
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.692
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.794
# Epoch: [2]  [ 0/60]  eta: 0:01:07  lr: 0.005000  loss: 0.3039 (0.3039)  loss_classifier: 0.0615 (0.0615)  loss_box_reg: 0.0507 (0.0507)  loss_mask: 0.1612 (0.1612)  loss_objectness: 0.0005 (0.0005)  loss_rpn_box_reg: 0.0299 (0.0299)  time: 1.1323  data: 0.4415  max mem: 3010
# Epoch: [2]  [10/60]  eta: 0:00:32  lr: 0.005000  loss: 0.2080 (0.2292)  loss_classifier: 0.0288 (0.0312)  loss_box_reg: 0.0266 (0.0314)  loss_mask: 0.1395 (0.1542)  loss_objectness: 0.0009 (0.0011)  loss_rpn_box_reg: 0.0108 (0.0114)  time: 0.6440  data: 0.0433  max mem: 3010
# Epoch: [2]  [20/60]  eta: 0:00:25  lr: 0.005000  loss: 0.2019 (0.2181)  loss_classifier: 0.0288 (0.0317)  loss_box_reg: 0.0254 (0.0284)  loss_mask: 0.1338 (0.1460)  loss_objectness: 0.0007 (0.0013)  loss_rpn_box_reg: 0.0097 (0.0108)  time: 0.6077  data: 0.0041  max mem: 3010
# Epoch: [2]  [30/60]  eta: 0:00:18  lr: 0.005000  loss: 0.1968 (0.2174)  loss_classifier: 0.0311 (0.0322)  loss_box_reg: 0.0214 (0.0289)  loss_mask: 0.1235 (0.1439)  loss_objectness: 0.0007 (0.0012)  loss_rpn_box_reg: 0.0090 (0.0113)  time: 0.6151  data: 0.0048  max mem: 3010
# Epoch: [2]  [40/60]  eta: 0:00:12  lr: 0.005000  loss: 0.2035 (0.2193)  loss_classifier: 0.0242 (0.0317)  loss_box_reg: 0.0206 (0.0276)  loss_mask: 0.1413 (0.1478)  loss_objectness: 0.0008 (0.0012)  loss_rpn_box_reg: 0.0091 (0.0111)  time: 0.6420  data: 0.0050  max mem: 3010
# Epoch: [2]  [50/60]  eta: 0:00:06  lr: 0.005000  loss: 0.1880 (0.2177)  loss_classifier: 0.0242 (0.0326)  loss_box_reg: 0.0126 (0.0271)  loss_mask: 0.1346 (0.1455)  loss_objectness: 0.0005 (0.0011)  loss_rpn_box_reg: 0.0091 (0.0114)  time: 0.6461  data: 0.0048  max mem: 3229
# Epoch: [2]  [59/60]  eta: 0:00:00  lr: 0.005000  loss: 0.1836 (0.2144)  loss_classifier: 0.0306 (0.0320)  loss_box_reg: 0.0141 (0.0257)  loss_mask: 0.1278 (0.1443)  loss_objectness: 0.0003 (0.0011)  loss_rpn_box_reg: 0.0088 (0.0111)  time: 0.6097  data: 0.0046  max mem: 3229
# Epoch: [2] Total time: 0:00:37 (0.6312 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:23  model_time: 0.1277 (0.1277)  evaluator_time: 0.0123 (0.0123)  time: 0.4777  data: 0.3367  max mem: 3229
# Test:  [49/50]  eta: 0:00:00  model_time: 0.1067 (0.1105)  evaluator_time: 0.0033 (0.0059)  time: 0.1189  data: 0.0023  max mem: 3229
# Test: Total time: 0:00:06 (0.1274 s / it)
# Averaged stats: model_time: 0.1067 (0.1105)  evaluator_time: 0.0033 (0.0059)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.790
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.970
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.917
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.589
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.819
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.325
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.850
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.850
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.783
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.857
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.762
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.970
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.936
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.534
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.800
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.302
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.813
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.813
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.717
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.823
# Epoch: [3]  [ 0/60]  eta: 0:01:15  lr: 0.000500  loss: 0.2751 (0.2751)  loss_classifier: 0.0593 (0.0593)  loss_box_reg: 0.0424 (0.0424)  loss_mask: 0.1632 (0.1632)  loss_objectness: 0.0002 (0.0002)  loss_rpn_box_reg: 0.0100 (0.0100)  time: 1.2573  data: 0.5462  max mem: 3229
# Epoch: [3]  [10/60]  eta: 0:00:33  lr: 0.000500  loss: 0.1995 (0.1998)  loss_classifier: 0.0376 (0.0369)  loss_box_reg: 0.0133 (0.0190)  loss_mask: 0.1335 (0.1326)  loss_objectness: 0.0007 (0.0016)  loss_rpn_box_reg: 0.0100 (0.0098)  time: 0.6611  data: 0.0519  max mem: 3229
# Epoch: [3]  [20/60]  eta: 0:00:25  lr: 0.000500  loss: 0.1701 (0.1865)  loss_classifier: 0.0267 (0.0318)  loss_box_reg: 0.0129 (0.0175)  loss_mask: 0.1160 (0.1276)  loss_objectness: 0.0005 (0.0010)  loss_rpn_box_reg: 0.0086 (0.0086)  time: 0.6082  data: 0.0036  max mem: 3231
# Epoch: [3]  [30/60]  eta: 0:00:18  lr: 0.000500  loss: 0.1668 (0.1844)  loss_classifier: 0.0267 (0.0322)  loss_box_reg: 0.0119 (0.0172)  loss_mask: 0.1129 (0.1248)  loss_objectness: 0.0003 (0.0015)  loss_rpn_box_reg: 0.0067 (0.0087)  time: 0.6134  data: 0.0045  max mem: 3231
# Epoch: [3]  [40/60]  eta: 0:00:12  lr: 0.000500  loss: 0.1552 (0.1831)  loss_classifier: 0.0259 (0.0312)  loss_box_reg: 0.0114 (0.0161)  loss_mask: 0.1129 (0.1258)  loss_objectness: 0.0002 (0.0013)  loss_rpn_box_reg: 0.0061 (0.0087)  time: 0.5965  data: 0.0045  max mem: 3231
# Epoch: [3]  [50/60]  eta: 0:00:06  lr: 0.000500  loss: 0.1424 (0.1787)  loss_classifier: 0.0218 (0.0302)  loss_box_reg: 0.0077 (0.0155)  loss_mask: 0.1097 (0.1235)  loss_objectness: 0.0003 (0.0012)  loss_rpn_box_reg: 0.0057 (0.0084)  time: 0.5870  data: 0.0045  max mem: 3231
# Epoch: [3]  [59/60]  eta: 0:00:00  lr: 0.000500  loss: 0.1526 (0.1820)  loss_classifier: 0.0218 (0.0313)  loss_box_reg: 0.0096 (0.0163)  loss_mask: 0.1116 (0.1242)  loss_objectness: 0.0004 (0.0012)  loss_rpn_box_reg: 0.0057 (0.0089)  time: 0.6101  data: 0.0046  max mem: 3231
# Epoch: [3] Total time: 0:00:37 (0.6179 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:23  model_time: 0.1252 (0.1252)  evaluator_time: 0.0110 (0.0110)  time: 0.4738  data: 0.3366  max mem: 3231
# Test:  [49/50]  eta: 0:00:00  model_time: 0.1067 (0.1095)  evaluator_time: 0.0038 (0.0050)  time: 0.1164  data: 0.0022  max mem: 3231
# Test: Total time: 0:00:06 (0.1258 s / it)
# Averaged stats: model_time: 0.1067 (0.1095)  evaluator_time: 0.0038 (0.0050)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.810
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.989
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.944
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.593
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.824
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.337
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.849
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.849
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.775
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.856
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.783
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.989
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.957
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.528
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.800
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.318
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.818
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.818
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.725
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.827
# Epoch: [4]  [ 0/60]  eta: 0:00:50  lr: 0.000500  loss: 0.1187 (0.1187)  loss_classifier: 0.0103 (0.0103)  loss_box_reg: 0.0047 (0.0047)  loss_mask: 0.0972 (0.0972)  loss_objectness: 0.0003 (0.0003)  loss_rpn_box_reg: 0.0062 (0.0062)  time: 0.8402  data: 0.3446  max mem: 3231
# Epoch: [4]  [10/60]  eta: 0:00:30  lr: 0.000500  loss: 0.1356 (0.1483)  loss_classifier: 0.0192 (0.0207)  loss_box_reg: 0.0072 (0.0098)  loss_mask: 0.1068 (0.1109)  loss_objectness: 0.0003 (0.0004)  loss_rpn_box_reg: 0.0063 (0.0065)  time: 0.6134  data: 0.0354  max mem: 3231
# Epoch: [4]  [20/60]  eta: 0:00:24  lr: 0.000500  loss: 0.1589 (0.1681)  loss_classifier: 0.0231 (0.0246)  loss_box_reg: 0.0088 (0.0127)  loss_mask: 0.1102 (0.1214)  loss_objectness: 0.0004 (0.0016)  loss_rpn_box_reg: 0.0070 (0.0077)  time: 0.6088  data: 0.0044  max mem: 3231
# Epoch: [4]  [30/60]  eta: 0:00:18  lr: 0.000500  loss: 0.1666 (0.1704)  loss_classifier: 0.0260 (0.0265)  loss_box_reg: 0.0113 (0.0135)  loss_mask: 0.1238 (0.1209)  loss_objectness: 0.0008 (0.0015)  loss_rpn_box_reg: 0.0081 (0.0080)  time: 0.6380  data: 0.0045  max mem: 3320
# Epoch: [4]  [40/60]  eta: 0:00:12  lr: 0.000500  loss: 0.1611 (0.1738)  loss_classifier: 0.0261 (0.0271)  loss_box_reg: 0.0127 (0.0145)  loss_mask: 0.1182 (0.1229)  loss_objectness: 0.0004 (0.0012)  loss_rpn_box_reg: 0.0073 (0.0081)  time: 0.6691  data: 0.0050  max mem: 3375
# Epoch: [4]  [50/60]  eta: 0:00:06  lr: 0.000500  loss: 0.1768 (0.1750)  loss_classifier: 0.0263 (0.0278)  loss_box_reg: 0.0131 (0.0145)  loss_mask: 0.1182 (0.1230)  loss_objectness: 0.0003 (0.0012)  loss_rpn_box_reg: 0.0089 (0.0086)  time: 0.6754  data: 0.0054  max mem: 3375
# Epoch: [4]  [59/60]  eta: 0:00:00  lr: 0.000500  loss: 0.1777 (0.1764)  loss_classifier: 0.0263 (0.0279)  loss_box_reg: 0.0141 (0.0146)  loss_mask: 0.1216 (0.1240)  loss_objectness: 0.0005 (0.0014)  loss_rpn_box_reg: 0.0086 (0.0086)  time: 0.6487  data: 0.0052  max mem: 3375
# Epoch: [4] Total time: 0:00:38 (0.6472 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:24  model_time: 0.1249 (0.1249)  evaluator_time: 0.0100 (0.0100)  time: 0.4881  data: 0.3521  max mem: 3375
# Test:  [49/50]  eta: 0:00:00  model_time: 0.1061 (0.1095)  evaluator_time: 0.0034 (0.0048)  time: 0.1171  data: 0.0023  max mem: 3375
# Test: Total time: 0:00:06 (0.1263 s / it)
# Averaged stats: model_time: 0.1061 (0.1095)  evaluator_time: 0.0034 (0.0048)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.819
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.992
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.927
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.594
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.833
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.340
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.858
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.858
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.767
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.867
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.785
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.992
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.966
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.521
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.801
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.317
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.818
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.818
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.708
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.829
# Epoch: [5]  [ 0/60]  eta: 0:01:09  lr: 0.000500  loss: 0.1491 (0.1491)  loss_classifier: 0.0188 (0.0188)  loss_box_reg: 0.0079 (0.0079)  loss_mask: 0.1115 (0.1115)  loss_objectness: 0.0002 (0.0002)  loss_rpn_box_reg: 0.0106 (0.0106)  time: 1.1620  data: 0.4765  max mem: 3375
# Epoch: [5]  [10/60]  eta: 0:00:36  lr: 0.000500  loss: 0.1766 (0.1869)  loss_classifier: 0.0369 (0.0357)  loss_box_reg: 0.0130 (0.0173)  loss_mask: 0.1188 (0.1228)  loss_objectness: 0.0006 (0.0007)  loss_rpn_box_reg: 0.0106 (0.0104)  time: 0.7321  data: 0.0466  max mem: 3875
# Epoch: [5]  [20/60]  eta: 0:00:27  lr: 0.000500  loss: 0.1634 (0.1809)  loss_classifier: 0.0274 (0.0307)  loss_box_reg: 0.0123 (0.0155)  loss_mask: 0.1188 (0.1237)  loss_objectness: 0.0006 (0.0007)  loss_rpn_box_reg: 0.0084 (0.0103)  time: 0.6728  data: 0.0043  max mem: 3875
# Epoch: [5]  [30/60]  eta: 0:00:20  lr: 0.000500  loss: 0.1548 (0.1786)  loss_classifier: 0.0203 (0.0298)  loss_box_reg: 0.0085 (0.0151)  loss_mask: 0.1192 (0.1229)  loss_objectness: 0.0003 (0.0007)  loss_rpn_box_reg: 0.0085 (0.0101)  time: 0.6470  data: 0.0048  max mem: 3875
# Epoch: [5]  [40/60]  eta: 0:00:13  lr: 0.000500  loss: 0.1637 (0.1809)  loss_classifier: 0.0236 (0.0296)  loss_box_reg: 0.0105 (0.0155)  loss_mask: 0.1241 (0.1259)  loss_objectness: 0.0002 (0.0006)  loss_rpn_box_reg: 0.0062 (0.0092)  time: 0.6560  data: 0.0049  max mem: 3875
# Epoch: [5]  [50/60]  eta: 0:00:06  lr: 0.000500  loss: 0.1607 (0.1759)  loss_classifier: 0.0240 (0.0280)  loss_box_reg: 0.0104 (0.0147)  loss_mask: 0.1149 (0.1238)  loss_objectness: 0.0003 (0.0007)  loss_rpn_box_reg: 0.0052 (0.0087)  time: 0.6393  data: 0.0048  max mem: 3875
# Epoch: [5]  [59/60]  eta: 0:00:00  lr: 0.000500  loss: 0.1435 (0.1712)  loss_classifier: 0.0200 (0.0272)  loss_box_reg: 0.0089 (0.0138)  loss_mask: 0.1042 (0.1214)  loss_objectness: 0.0003 (0.0006)  loss_rpn_box_reg: 0.0051 (0.0083)  time: 0.5983  data: 0.0046  max mem: 3875
# Epoch: [5] Total time: 0:00:39 (0.6517 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:23  model_time: 0.1217 (0.1217)  evaluator_time: 0.0109 (0.0109)  time: 0.4794  data: 0.3458  max mem: 3875
# Test:  [49/50]  eta: 0:00:00  model_time: 0.1066 (0.1097)  evaluator_time: 0.0034 (0.0048)  time: 0.1168  data: 0.0023  max mem: 3875
# Test: Total time: 0:00:06 (0.1261 s / it)
# Averaged stats: model_time: 0.1066 (0.1097)  evaluator_time: 0.0034 (0.0048)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.823
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.992
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.945
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.632
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.834
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.347
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.860
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.860
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.775
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.869
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.787
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.992
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.966
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.532
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.802
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.318
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.818
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.818
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.717
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.828
# Epoch: [6]  [ 0/60]  eta: 0:00:58  lr: 0.000050  loss: 0.1286 (0.1286)  loss_classifier: 0.0177 (0.0177)  loss_box_reg: 0.0067 (0.0067)  loss_mask: 0.1001 (0.1001)  loss_objectness: 0.0004 (0.0004)  loss_rpn_box_reg: 0.0036 (0.0036)  time: 0.9720  data: 0.3845  max mem: 3875
# Epoch: [6]  [10/60]  eta: 0:00:31  lr: 0.000050  loss: 0.1452 (0.1824)  loss_classifier: 0.0220 (0.0300)  loss_box_reg: 0.0067 (0.0158)  loss_mask: 0.1193 (0.1276)  loss_objectness: 0.0004 (0.0006)  loss_rpn_box_reg: 0.0052 (0.0085)  time: 0.6271  data: 0.0383  max mem: 3875
# Epoch: [6]  [20/60]  eta: 0:00:24  lr: 0.000050  loss: 0.1710 (0.1778)  loss_classifier: 0.0235 (0.0294)  loss_box_reg: 0.0108 (0.0146)  loss_mask: 0.1188 (0.1246)  loss_objectness: 0.0002 (0.0005)  loss_rpn_box_reg: 0.0084 (0.0087)  time: 0.6053  data: 0.0041  max mem: 3875
# Epoch: [6]  [30/60]  eta: 0:00:18  lr: 0.000050  loss: 0.1604 (0.1749)  loss_classifier: 0.0223 (0.0284)  loss_box_reg: 0.0097 (0.0142)  loss_mask: 0.1188 (0.1230)  loss_objectness: 0.0002 (0.0006)  loss_rpn_box_reg: 0.0081 (0.0086)  time: 0.6125  data: 0.0045  max mem: 3875
# Epoch: [6]  [40/60]  eta: 0:00:12  lr: 0.000050  loss: 0.1573 (0.1702)  loss_classifier: 0.0196 (0.0278)  loss_box_reg: 0.0090 (0.0136)  loss_mask: 0.1088 (0.1198)  loss_objectness: 0.0002 (0.0006)  loss_rpn_box_reg: 0.0081 (0.0084)  time: 0.6298  data: 0.0047  max mem: 3875
# Epoch: [6]  [50/60]  eta: 0:00:06  lr: 0.000050  loss: 0.1552 (0.1685)  loss_classifier: 0.0214 (0.0278)  loss_box_reg: 0.0090 (0.0131)  loss_mask: 0.1060 (0.1188)  loss_objectness: 0.0002 (0.0006)  loss_rpn_box_reg: 0.0079 (0.0083)  time: 0.6644  data: 0.0050  max mem: 3875
# Epoch: [6]  [59/60]  eta: 0:00:00  lr: 0.000050  loss: 0.1492 (0.1677)  loss_classifier: 0.0213 (0.0272)  loss_box_reg: 0.0078 (0.0129)  loss_mask: 0.1090 (0.1190)  loss_objectness: 0.0002 (0.0007)  loss_rpn_box_reg: 0.0061 (0.0079)  time: 0.6457  data: 0.0049  max mem: 3875
# Epoch: [6] Total time: 0:00:38 (0.6343 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:24  model_time: 0.1214 (0.1214)  evaluator_time: 0.0110 (0.0110)  time: 0.4878  data: 0.3543  max mem: 3875
# Test:  [49/50]  eta: 0:00:00  model_time: 0.1120 (0.1115)  evaluator_time: 0.0034 (0.0049)  time: 0.1212  data: 0.0023  max mem: 3875
# Test: Total time: 0:00:06 (0.1282 s / it)
# Averaged stats: model_time: 0.1120 (0.1115)  evaluator_time: 0.0034 (0.0049)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.825
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.992
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.945
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.633
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.836
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.348
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.862
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.862
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.775
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.871
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.785
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.992
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.957
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.534
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.801
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.320
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.818
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.818
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.717
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.828
# Epoch: [7]  [ 0/60]  eta: 0:01:03  lr: 0.000050  loss: 0.1465 (0.1465)  loss_classifier: 0.0167 (0.0167)  loss_box_reg: 0.0065 (0.0065)  loss_mask: 0.1170 (0.1170)  loss_objectness: 0.0001 (0.0001)  loss_rpn_box_reg: 0.0061 (0.0061)  time: 1.0550  data: 0.3721  max mem: 3875
# Epoch: [7]  [10/60]  eta: 0:00:34  lr: 0.000050  loss: 0.1786 (0.1772)  loss_classifier: 0.0254 (0.0260)  loss_box_reg: 0.0114 (0.0164)  loss_mask: 0.1182 (0.1227)  loss_objectness: 0.0004 (0.0008)  loss_rpn_box_reg: 0.0109 (0.0112)  time: 0.6939  data: 0.0378  max mem: 3875
# Epoch: [7]  [20/60]  eta: 0:00:26  lr: 0.000050  loss: 0.1691 (0.1704)  loss_classifier: 0.0254 (0.0267)  loss_box_reg: 0.0114 (0.0145)  loss_mask: 0.1181 (0.1194)  loss_objectness: 0.0004 (0.0008)  loss_rpn_box_reg: 0.0074 (0.0090)  time: 0.6495  data: 0.0046  max mem: 3875
# Epoch: [7]  [30/60]  eta: 0:00:20  lr: 0.000050  loss: 0.1505 (0.1777)  loss_classifier: 0.0224 (0.0289)  loss_box_reg: 0.0107 (0.0161)  loss_mask: 0.1151 (0.1217)  loss_objectness: 0.0003 (0.0015)  loss_rpn_box_reg: 0.0073 (0.0096)  time: 0.6590  data: 0.0048  max mem: 3875
# Epoch: [7]  [40/60]  eta: 0:00:13  lr: 0.000050  loss: 0.1672 (0.1768)  loss_classifier: 0.0247 (0.0288)  loss_box_reg: 0.0115 (0.0150)  loss_mask: 0.1193 (0.1230)  loss_objectness: 0.0003 (0.0013)  loss_rpn_box_reg: 0.0072 (0.0088)  time: 0.6653  data: 0.0047  max mem: 3876
# Epoch: [7]  [50/60]  eta: 0:00:06  lr: 0.000050  loss: 0.1631 (0.1730)  loss_classifier: 0.0209 (0.0270)  loss_box_reg: 0.0095 (0.0141)  loss_mask: 0.1163 (0.1224)  loss_objectness: 0.0002 (0.0011)  loss_rpn_box_reg: 0.0058 (0.0084)  time: 0.6291  data: 0.0046  max mem: 3876
# Epoch: [7]  [59/60]  eta: 0:00:00  lr: 0.000050  loss: 0.1455 (0.1710)  loss_classifier: 0.0180 (0.0262)  loss_box_reg: 0.0073 (0.0134)  loss_mask: 0.1077 (0.1222)  loss_objectness: 0.0002 (0.0010)  loss_rpn_box_reg: 0.0050 (0.0082)  time: 0.5955  data: 0.0047  max mem: 3876
# Epoch: [7] Total time: 0:00:38 (0.6457 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:23  model_time: 0.1200 (0.1200)  evaluator_time: 0.0096 (0.0096)  time: 0.4748  data: 0.3443  max mem: 3876
# Test:  [49/50]  eta: 0:00:00  model_time: 0.1074 (0.1094)  evaluator_time: 0.0034 (0.0048)  time: 0.1165  data: 0.0023  max mem: 3876
# Test: Total time: 0:00:06 (0.1257 s / it)
# Averaged stats: model_time: 0.1074 (0.1094)  evaluator_time: 0.0034 (0.0048)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.824
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.992
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.946
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.625
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.835
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.347
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.860
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.860
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.767
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.870
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.784
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.992
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.957
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.531
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.800
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.321
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.818
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.818
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.717
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.828
# Epoch: [8]  [ 0/60]  eta: 0:01:07  lr: 0.000050  loss: 0.1429 (0.1429)  loss_classifier: 0.0252 (0.0252)  loss_box_reg: 0.0128 (0.0128)  loss_mask: 0.0947 (0.0947)  loss_objectness: 0.0005 (0.0005)  loss_rpn_box_reg: 0.0096 (0.0096)  time: 1.1322  data: 0.3709  max mem: 3876
# Epoch: [8]  [10/60]  eta: 0:00:32  lr: 0.000050  loss: 0.1510 (0.1660)  loss_classifier: 0.0230 (0.0245)  loss_box_reg: 0.0118 (0.0128)  loss_mask: 0.1082 (0.1183)  loss_objectness: 0.0005 (0.0018)  loss_rpn_box_reg: 0.0080 (0.0086)  time: 0.6448  data: 0.0378  max mem: 3876
# Epoch: [8]  [20/60]  eta: 0:00:25  lr: 0.000050  loss: 0.1501 (0.1597)  loss_classifier: 0.0230 (0.0245)  loss_box_reg: 0.0100 (0.0114)  loss_mask: 0.1077 (0.1154)  loss_objectness: 0.0003 (0.0011)  loss_rpn_box_reg: 0.0054 (0.0073)  time: 0.6193  data: 0.0047  max mem: 3876
# Epoch: [8]  [30/60]  eta: 0:00:18  lr: 0.000050  loss: 0.1527 (0.1718)  loss_classifier: 0.0235 (0.0270)  loss_box_reg: 0.0104 (0.0136)  loss_mask: 0.1136 (0.1223)  loss_objectness: 0.0002 (0.0009)  loss_rpn_box_reg: 0.0057 (0.0080)  time: 0.6213  data: 0.0049  max mem: 3876
# Epoch: [8]  [40/60]  eta: 0:00:12  lr: 0.000050  loss: 0.1648 (0.1721)  loss_classifier: 0.0234 (0.0266)  loss_box_reg: 0.0104 (0.0136)  loss_mask: 0.1199 (0.1231)  loss_objectness: 0.0003 (0.0011)  loss_rpn_box_reg: 0.0068 (0.0077)  time: 0.6046  data: 0.0049  max mem: 3876
# Epoch: [8]  [50/60]  eta: 0:00:06  lr: 0.000050  loss: 0.1457 (0.1691)  loss_classifier: 0.0178 (0.0260)  loss_box_reg: 0.0074 (0.0131)  loss_mask: 0.1078 (0.1211)  loss_objectness: 0.0003 (0.0010)  loss_rpn_box_reg: 0.0055 (0.0080)  time: 0.6153  data: 0.0047  max mem: 3876
# Epoch: [8]  [59/60]  eta: 0:00:00  lr: 0.000050  loss: 0.1528 (0.1706)  loss_classifier: 0.0211 (0.0268)  loss_box_reg: 0.0089 (0.0133)  loss_mask: 0.1127 (0.1215)  loss_objectness: 0.0004 (0.0011)  loss_rpn_box_reg: 0.0082 (0.0079)  time: 0.6205  data: 0.0047  max mem: 3876
# Epoch: [8] Total time: 0:00:37 (0.6264 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:29  model_time: 0.1209 (0.1209)  evaluator_time: 0.0097 (0.0097)  time: 0.5940  data: 0.4624  max mem: 3876
# Test:  [49/50]  eta: 0:00:00  model_time: 0.1156 (0.1150)  evaluator_time: 0.0038 (0.0050)  time: 0.1276  data: 0.0026  max mem: 3876
# Test: Total time: 0:00:06 (0.1337 s / it)
# Averaged stats: model_time: 0.1156 (0.1150)  evaluator_time: 0.0038 (0.0050)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.823
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.992
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.946
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.625
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.834
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.346
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.860
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.860
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.767
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.869
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.788
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.992
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.957
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.533
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.803
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.321
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.820
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.820
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.717
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.830
# Epoch: [9]  [ 0/60]  eta: 0:01:12  lr: 0.000005  loss: 0.2012 (0.2012)  loss_classifier: 0.0386 (0.0386)  loss_box_reg: 0.0128 (0.0128)  loss_mask: 0.1363 (0.1363)  loss_objectness: 0.0002 (0.0002)  loss_rpn_box_reg: 0.0133 (0.0133)  time: 1.2103  data: 0.3554  max mem: 3876
# Epoch: [9]  [10/60]  eta: 0:00:34  lr: 0.000005  loss: 0.1536 (0.1517)  loss_classifier: 0.0228 (0.0243)  loss_box_reg: 0.0099 (0.0103)  loss_mask: 0.1104 (0.1095)  loss_objectness: 0.0002 (0.0002)  loss_rpn_box_reg: 0.0078 (0.0074)  time: 0.6938  data: 0.0359  max mem: 3876
# Epoch: [9]  [20/60]  eta: 0:00:27  lr: 0.000005  loss: 0.1518 (0.1664)  loss_classifier: 0.0228 (0.0276)  loss_box_reg: 0.0072 (0.0129)  loss_mask: 0.1104 (0.1173)  loss_objectness: 0.0002 (0.0004)  loss_rpn_box_reg: 0.0078 (0.0082)  time: 0.6647  data: 0.0051  max mem: 3876
# Epoch: [9]  [30/60]  eta: 0:00:20  lr: 0.000005  loss: 0.1518 (0.1716)  loss_classifier: 0.0261 (0.0272)  loss_box_reg: 0.0106 (0.0140)  loss_mask: 0.1181 (0.1214)  loss_objectness: 0.0006 (0.0006)  loss_rpn_box_reg: 0.0096 (0.0084)  time: 0.6642  data: 0.0054  max mem: 3876
# Epoch: [9]  [40/60]  eta: 0:00:13  lr: 0.000005  loss: 0.1490 (0.1670)  loss_classifier: 0.0247 (0.0259)  loss_box_reg: 0.0082 (0.0132)  loss_mask: 0.1084 (0.1196)  loss_objectness: 0.0003 (0.0005)  loss_rpn_box_reg: 0.0061 (0.0077)  time: 0.6114  data: 0.0047  max mem: 3876
# Epoch: [9]  [50/60]  eta: 0:00:06  lr: 0.000005  loss: 0.1253 (0.1637)  loss_classifier: 0.0197 (0.0258)  loss_box_reg: 0.0056 (0.0126)  loss_mask: 0.0991 (0.1177)  loss_objectness: 0.0002 (0.0005)  loss_rpn_box_reg: 0.0045 (0.0072)  time: 0.5835  data: 0.0047  max mem: 3876
# Epoch: [9]  [59/60]  eta: 0:00:00  lr: 0.000005  loss: 0.1542 (0.1679)  loss_classifier: 0.0241 (0.0269)  loss_box_reg: 0.0112 (0.0132)  loss_mask: 0.1031 (0.1191)  loss_objectness: 0.0003 (0.0007)  loss_rpn_box_reg: 0.0080 (0.0080)  time: 0.6325  data: 0.0048  max mem: 3876
# Epoch: [9] Total time: 0:00:38 (0.6486 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:23  model_time: 0.1207 (0.1207)  evaluator_time: 0.0106 (0.0106)  time: 0.4750  data: 0.3426  max mem: 3876
# Test:  [49/50]  eta: 0:00:00  model_time: 0.1075 (0.1100)  evaluator_time: 0.0034 (0.0049)  time: 0.1168  data: 0.0023  max mem: 3876
# Test: Total time: 0:00:06 (0.1266 s / it)
# Averaged stats: model_time: 0.1075 (0.1100)  evaluator_time: 0.0034 (0.0049)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.822
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.992
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.946
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.625
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.833
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.345
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.860
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.860
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.767
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.869
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.788
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.992
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.957
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.533
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.802
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.321
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.818
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.818
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.717
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.829
# That's it!
