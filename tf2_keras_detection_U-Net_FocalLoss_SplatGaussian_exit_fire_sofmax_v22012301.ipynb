# %%
# Francisco Dominguez Mateos# Francisco Dominguez Mateos
# Kernel dml
#24/03/2021 Some tuning and this works
# Initial code and auxiliar functions. Don't pay attention to this
# 03/12/2021
# Splating lables idea from: https://medium.com/visionwizard/centernet-objects-as-points-a-comprehensive-guide-2ed9993c48bc
# and using FocalLoss  from: https://keras.io/examples/vision/retinanet/
import os
import random
import numpy as np
import matplotlib.pyplot as plt
import cv2
# Config the matplotlib backend as plotting inline in IPython
# %matplotlib inline

# %%
#! pip install untangle
# The easiest way to parse xml files I have found.
import untangle

# %%
# dlib image object detection dataset xml file format
basepath='/home/francisco/datasets/datasets/pictures/indoor_object_detection_dataset/faster_bounding_box_dataset/all'
filename='exit_fire.xml'
obj=untangle.parse(filename)
len(obj.dataset.images.image)
# Out:
# 1086

# %%
def fillRec(img,x,y,w,h,label):
    img[y:y+h,x:x+w,label]=1

def fillRecSoftMax(img,x,y,w,h,label):
    img[y-1:y+h+2,x-1:x+w+2,    0]=0
    img[y-1:y+h+2,x-1:x+w+2,label]=1.0
    
def fillRecSoftMax_OLD(img,x,y,w,h,label):
    for i in range(w+1):
        for j in range(h+1):
            nx=x+i
            if nx>=img.shape[1]: nx=img.shape[1]-1
            if nx<0: nx=0
            ny=y+j
            if ny>=img.shape[0]: ny=img.shape[0]-1
            if ny<0: ny=0
            img[ny,nx,0]=0
            img[ny,nx,label]=1
            
def setCenter(img,top,left,width,height):
    center_x=left+width//2
    center_y=top +height//2
    y[center_y,center_x,0]=1

def buildEllipse(im,left,top,width,height,scale=4):
    img=np.zeros((im.shape[0],im.shape[1],1))
    center_x=left+width //2
    center_y=top +height//2
    widthS  =width //scale
    heightS =height//scale
    #print(topN,leftN,widthS,heightS)
    #image = cv2.ellipse(image, center_coordinates, axesLength, angle, startAngle, endAngle, color, thickness)
    cv2.ellipse(img,(center_x,center_y),(widthS,heightS),0,0,360,1,-1)
    return img
    
def setCenterSplat(img,left,top,width,height):
    img_msk=buildEllipse(img,left,top,width,height)
    #print(img.shape,img_msk.shape)
    blur = cv2.GaussianBlur(img_msk,(7,7),0)
    #blur=img_msk[:,:,0]
    blur=blur/np.max(blur)
    #print(blur.shape)
    return blur
    
def fillCenterSplatSoftMax(img,x,y,w,h,label):
    img_label=img[:,:,label]
    img_msk=setCenterSplat(img,x,y,w,h)
    img_label=np.maximum(img_label,img_msk)
    img[:,:,label]=img_label
    img[:,:,0    ]=np.logical_and(img[:,:,0],img_label[:,:]<0.1) # background label
    

def setBlackBackground(im):
    img=im.copy()
    #img[:,:,0]=0
    return img
                
def getLabel(box):
    l=b.label.cdata
    if l=="fireextinguisher":
        return 1
    if l=="exit":
        return 2
    return 0
    
def plt_img(imi,imo):
    #plt.imshow(imi.reshape(height_i,width_i,3))
    #plt.imshow(imi)
    width_i =imi.shape[1]
    height_i=imi.shape[0]
    #plt.show()
    #img_np=imo.reshape(height_o,width_o,3)
    img_np=imo #.reshape(height_o,width_o,3)
    img=cv2.resize(img_np,(width_i,height_i))
    print("--",img.shape,np.mean(img,axis=(0,1)))
    #plt.imshow(img,cmap='cool',alpha=0.25)
    img_bg=setBlackBackground(img)
    print("--",img_bg.shape,np.max(img_bg,axis=(0,1)))
    plt.imshow(img_bg,alpha=0.5)
    #plt.imshow(img)

# %%
img=np.zeros((256,256))
img_msk=setCenterSplat(img,10,150,10,40)
print(img_msk.shape)
print(np.max(img_msk))
img_o=np.zeros((img.shape[0],img.shape[1],3))
img_o[:,:,0]=img_msk
img_o[:,:,1]=img_msk[:,:]<0.1
print(img_o.shape)
plt.imshow(img_o)
plt.show()
# Out:
# (256, 256)
# 1.0
# (256, 256, 3)

# %%
img_msk0=setCenterSplat(img,40,152,40,10)
img_max=np.maximum(img_msk0,img_msk)
img_o=np.zeros((img.shape[0],img.shape[1],3))
img_o[:,:,0]=img_max
img_o[:,:,1]=img_max[:,:]<0.1
print(img_o.shape)
plt.imshow(img_o)
plt.show()
# Out:
# (256, 256, 3)

# %%
images=[]
labels=[]
scale    =4 # reduction of size of input images
reduction=2 # reduction of size from input to output
classes  =3 # exit, fireextinguisher, none

# %%
for i in obj.dataset.images.image[:]:
    imgfile=os.path.join(basepath,i['file'])
    #print(imgfile)
    img=cv2.imread(imgfile)
    img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    # resize and 
    # normalize very important!!
    img=img/255.0
    img=cv2.resize(img, (img.shape[1]//scale, img.shape[0]//scale))
    #print(i['file'],'\t',img.shape)
    height_i=img.shape[0]
    width_i =img.shape[1]
    height_o=height_i//reduction
    width_o =width_i //reduction
    y=np.zeros((height_o,width_o,classes))
    ones=np.ones((height_o,width_o))
    y[:,:,0]=ones # label 0= background
    for b in i.box:
        top   =int(b['top'   ])//scale//reduction
        left  =int(b['left'  ])//scale//reduction
        width =int(b['width' ])//scale//reduction
        height=int(b['height'])//scale//reduction
        label=getLabel(b)
        
        #setCenter(y,top,left,width,height)
        #fillRecSoftMax(y,left,top,width,height,label)
        fillCenterSplatSoftMax(y,left,top,width,height,label)
        #print("  ",b.label.cdata,"\t->\t[",top,",",left,",",width,",",height,"]")
        #cv2.rectangle(y, (left,top), (left+width,top+height), (1,0,1), 2)
        #cv2.ellipse(y, (left,top), (width,height),0,0,360,(1,100,1),-1)

    images.append(img)
    labels.append(y)

# %%
N_test=20
images_np=np.array(images)
y_train=np.array(labels[:-N_test])
y_test =np.array(labels[:N_test])
print(images_np.shape)
x_train=images_np[:-N_test]
x_test =images_np[:N_test]
idx=random.randint(0,y_train.shape[0])
print(x_train[idx].shape)
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
print(np.min(y_train,axis=(0,1,2)),np.max(y_train,axis=(0,1,2)),np.mean(y_train,axis=(0,1,2)))
# Out:
# (1086, 180, 320, 3)
# (180, 320, 3)
# (1066, 180, 320, 3)
# (1066, 90, 160, 3)
# (20, 180, 320, 3)
# (20, 90, 160, 3)
# [0. 0. 0.] [1. 1. 1.] [0.9871477  0.00517558 0.00162187]

# %%
for i in range(5):
    idx=random.randint(0,y_train.shape[0]-1)
    plt.figure()
    #print(np.mean(y_train,axis=(0,1,2)))
    plt_img(x_train[idx],y_train[idx])
    #print(np.mean(y_train,axis=(0,1,2)))
plt.show()
# Out:
# -- (180, 320, 3) [0.9925     0.0010306  0.00233028]
# -- (180, 320, 3) [0.         0.0010306  0.00233028]
# -- (180, 320, 3) [0.98715278 0.00335793 0.00341612]
# -- (180, 320, 3) [0.         0.00335793 0.00341612]
# -- (180, 320, 3) [0.98034722 0.         0.013125  ]
# -- (180, 320, 3) [0.       0.       0.013125]
# -- (180, 320, 3) [0.99743056 0.00106773 0.        ]
# -- (180, 320, 3) [0.         0.00106773 0.        ]
# -- (180, 320, 3) [0.99229167 0.         0.00417482]
# -- (180, 320, 3) [0.         0.         0.00417482]

# %%
import tensorflow.keras
from tensorflow.keras.models import Model,Sequential,load_model
from tensorflow.keras.layers import Input,Dense, Dropout,Flatten, LeakyReLU, concatenate
from tensorflow.keras.layers import Conv2D, MaxPooling2D, BatchNormalization, Activation, Conv2DTranspose
from tensorflow.keras.optimizers import RMSprop, Adam
from tensorflow.keras.utils import to_categorical
import tensorflow.keras.metrics as tfm
from tensorflow.keras import backend as K
import tensorflow as tf
print("tf=   ",tf.__version__)
print("keras=",tf.keras.__version__)
# Out:
# tf=    2.4.1
# keras= 2.4.0

# %%
#from: https://github.com/tensorflow/tensorflow/issues/42182
class BinaryAccuracy(tfm.BinaryAccuracy):
    def __init__(self, from_logits=True, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self._from_logits = from_logits

    def update_state(self, y_true, y_pred, sample_weight=None):
        if self._from_logits:
            super(BinaryAccuracy, self).update_state(y_true, tf.nn.sigmoid(y_pred), sample_weight)
        else:
            super(BinaryAccuracy, self).update_state(y_true, y_pred, sample_weight)

# %%
#03/12/2021 from: https://keras.io/examples/vision/retinanet/
class FocalLoss(tf.losses.Loss):
    """Implements Focal loss"""

    def __init__(self, alpha=0.25, gamma=2.0):
        super(FocalLoss, self).__init__(
            reduction="none", name="FocalLoss"
        )
        self._alpha = alpha
        self._gamma = gamma
    # y_pred seem to be logits!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
    # lost seem to be sigmoid not softmax!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
    def call(self, y_true, y_pred):
        cross_entropy = tf.nn.sigmoid_cross_entropy_with_logits(
            labels=y_true, logits=y_pred
        )
        probs = tf.nn.sigmoid(y_pred)
        alpha = tf.where(tf.equal(y_true, 1.0), self._alpha, (1.0 - self._alpha))
        pt    = tf.where(tf.equal(y_true, 1.0), probs, 1 - probs)
        loss = alpha * tf.pow(1.0 - pt, self._gamma) * cross_entropy
        return tf.reduce_sum(loss, axis=-1)

# %%
def image_softmax(input):
    label_dim = -1
    d = K.exp(input - K.max(input, axis=label_dim, keepdims=True))
    return d / K.sum(d, axis=label_dim, keepdims=True)

__EPS = 1e-5
def image_categorical_crossentropy(y_true, y_pred):
    y_pred = K.clip(y_pred, __EPS, 1 - __EPS)
    return -K.mean(y_true * K.log(y_pred) + (1 - y_true) * K.log(1 - y_pred))

# %%
#input_shape=(360,640,3)
# Dynamic Imput size
input_shape=(int(360/2),int(640/2),3)
#input_shape=(None,None,3)

input= Input(input_shape)
x=input
# Without BatchNormalization the model doesn't seem to learn
# (11/04/2019) actually I hadn't normalized the color images just I had to divide by 255
# (11/04/2019) with dropouts and without BatchNorm learn but slowly
c1 = Conv2D(32, 5,padding='same')(x)
c1 = BatchNormalization()(c1)
c1 = LeakyReLU()(c1)
p1 = MaxPooling2D(pool_size=(2, 2))(c1)

c2 = Conv2D(64, 3,padding='same')(p1)
c2 = BatchNormalization()(c2)
c2 = LeakyReLU()(c2)
p2 = MaxPooling2D(pool_size=(2, 2))(c2)

#c3 = Conv2D(128, 3,padding='same')(p2)
#c3 = BatchNormalization()(c3)
#c3 = LeakyReLU()(c3)
#p3 = MaxPooling2D(pool_size=(2, 2))(c3)

c5 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p2)
c5 = Dropout(0.5) (c5)
c5 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c5)

# receptive field aproximation 8(reduction)x3(convolution size)=24
#model.add(Conv2D(1, 3, 3, activation='sigmoid',border_mode='same'))
# receptive field aproximation 8(reduction)x5(convolution size)=40
# receptive field aproximation 8(reduction)x7(convolution size)=56

u8 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same') (c5)
u8 = concatenate([u8, c2])
c8 = Conv2D(64, (3, 3), kernel_initializer='he_normal', padding='same') (u8)
c8 = BatchNormalization()(c8)
c8 = LeakyReLU()(c8)
#c8 = Dropout(0.1) (c8)
c8 = Conv2D(64, (3, 3), kernel_initializer='he_normal', padding='same') (c8)
c8 = BatchNormalization()(c8)
c8 = LeakyReLU()(c8)

#u9 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (c8)
#u9 = concatenate([u9, c2], axis=3)
#c9 = Conv2D(32, (3, 3), kernel_initializer='he_normal', padding='same') (u9)
#c9 = BatchNormalization()(c9)
#c9 = LeakyReLU()(c9)
#c9 = Dropout(0.1) (c9)
#c9 = Conv2D(32, (3, 3), kernel_initializer='he_normal', padding='same') (c9)
#c9 = BatchNormalization()(c9)
#c9 = LeakyReLU()(c9)

# Last layer n filters = n outputs
#x = Conv2D(classes, 1, activation=image_softmax,padding='same')(c9)
#x = Conv2D(classes, 1, activation="softmax",padding='same')(c9)
# no activation since Focal Lost work with logits
x = Conv2D(classes, 1, padding='same')(c8)
model_train=Model(input,x)
x = Activation('sigmoid')(x)
model=Model(input,x)

# %%
#model.compile(loss=image_categorical_crossentropy,
#              optimizer=Adam(),
#              metrics=['accuracy'])
loss_fn=FocalLoss()
model_train.compile(loss=loss_fn,
              optimizer=Adam(),
              metrics=[BinaryAccuracy()])
              #metrics=['accuracy'])
model_train.summary()
model.compile()
# Out:
# Model: "model_9"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            [(None, 180, 320, 3) 0
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 180, 320, 32) 2432        input_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 180, 320, 32) 128         conv2d_35[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 180, 320, 32) 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 90, 160, 32)  0           leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 90, 160, 64)  18496       max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 90, 160, 64)  256         conv2d_36[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, 90, 160, 64)  0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 45, 80, 64)   0           leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 45, 80, 128)  73856       max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 45, 80, 128)  0           conv2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 45, 80, 128)  147584      dropout_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 90, 160, 64)  32832       conv2d_38[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 90, 160, 128) 0           conv2d_transpose_5[0][0]
#                                                                  leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 90, 160, 64)  73792       concatenate_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 90, 160, 64)  256         conv2d_39[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, 90, 160, 64)  0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 90, 160, 64)  36928       leaky_re_lu_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 90, 160, 64)  256         conv2d_40[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, 90, 160, 64)  0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 90, 160, 3)   195         leaky_re_lu_23[0][0]
# ==================================================================================================
# Total params: 387,011
# Trainable params: 386,563
# Non-trainable params: 448
# __________________________________________________________________________________________________

# %%
batch_size=20
epochs=10
history = model_train.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    validation_data=(x_test,y_test),
                    verbose=1)
# Out:
# Epoch 1/10
# 54/54 [==============================] - 7s 122ms/step - loss: 0.0016 - binary_accuracy: 0.9905 - val_loss: 8.8485e-04 - val_binary_accuracy: 0.9935
# Epoch 2/10
# 54/54 [==============================] - 7s 122ms/step - loss: 0.0016 - binary_accuracy: 0.9905 - val_loss: 0.0014 - val_binary_accuracy: 0.9924
# Epoch 3/10
# 54/54 [==============================] - 7s 123ms/step - loss: 0.0017 - binary_accuracy: 0.9904 - val_loss: 0.0010 - val_binary_accuracy: 0.9932
# Epoch 4/10
# 54/54 [==============================] - 7s 123ms/step - loss: 0.0016 - binary_accuracy: 0.9905 - val_loss: 0.0014 - val_binary_accuracy: 0.9931
# Epoch 5/10
# 54/54 [==============================] - 7s 124ms/step - loss: 0.0016 - binary_accuracy: 0.9906 - val_loss: 9.0995e-04 - val_binary_accuracy: 0.9934
# Epoch 6/10
# 54/54 [==============================] - 7s 125ms/step - loss: 0.0016 - binary_accuracy: 0.9905 - val_loss: 9.6581e-04 - val_binary_accuracy: 0.9932
# Epoch 7/10
# 54/54 [==============================] - 7s 125ms/step - loss: 0.0016 - binary_accuracy: 0.9905 - val_loss: 0.0010 - val_binary_accuracy: 0.9933
# Epoch 8/10
# 54/54 [==============================] - 7s 126ms/step - loss: 0.0015 - binary_accuracy: 0.9906 - val_loss: 7.5141e-04 - val_binary_accuracy: 0.9935
# Epoch 9/10
# 54/54 [==============================] - 7s 127ms/step - loss: 0.0015 - binary_accuracy: 0.9906 - val_loss: 0.0011 - val_binary_accuracy: 0.9928
# Epoch 10/10
# 54/54 [==============================] - 7s 127ms/step - loss: 0.0015 - binary_accuracy: 0.9905 - val_loss: 0.0010 - val_binary_accuracy: 0.9928

# %%
model.save(os.path.join('./','u-net-focal-loss-exit_fire.h5'))

# %%
model = load_model(os.path.join('./','u-net-focal-loss-exit_fire.h5'))

# %%
#score = model.evaluate(x_train, y_train, verbose=0)
#print('Train loss:', score[0])
#print('Train accuracy:', score[1])
#score = model.evaluate(x_test, y_test, verbose=0)
#print('Test loss:', score[0])
#print('Test accuracy:', score[1])

# %%
plt.figure(1,figsize=(25,50))
y_pred=model.predict(x_train[:50])
print(np.max(y_pred,axis=(0,1,2)))
print(np.min(y_pred,axis=(0,1,2)))
y_dif=np.abs(y_pred-y_train[:50])
for i in range(5):
    idx=random.randint(0,y_pred.shape[0]-1)
    #print(np.max(y_pred[idx]))
    #print(np.sum(y_dif[idx]/(height_o*width_o)))
    plt.subplot(10, 3, i*3+1)
    plt.imshow(x_train[idx].reshape(height_i,width_i,3))
    #plt.show()
    plt.subplot(10, 3, i*3+2)
    #plt.imshow(x_train[idx].reshape(height_i,width_i,3))
    #img_np=setBlackBackground(y_train[idx].reshape(height_o,width_o,3))
    #img=cv2.resize(img_np,(width_i,height_i))
    #plt.imshow(setBlackBackground(img),alpha=0.5)
    plt_img(x_train[idx],y_train[idx])
    #plt.show()
    plt.subplot(10, 3, i*3+3)
    #plt.imshow(setBlackBackground(y_pred[idx].reshape(height_o,width_o,3)))
    plt_img(x_train[idx],y_pred[idx])
    #plt.show()
    #plt.imshow(y_dif[idx].reshape(height_o,width_o),cmap="gray_r")
plt.show()
# Out:
# [0.99336594 0.3143178  0.23965476]
# [0.00431172 0.00159152 0.00099488]
# -- (180, 320, 3) [0.98006944 0.         0.01083333]
# -- (180, 320, 3) [1.        0.        0.9921875]
# -- (180, 320, 3) [0.9141792  0.03042871 0.0333118 ]
# -- (180, 320, 3) [0.9859759  0.09019867 0.20286714]
# -- (180, 320, 3) [0.98819444 0.00578174 0.        ]
# -- (180, 320, 3) [1.         0.97916667 0.        ]
# -- (180, 320, 3) [0.9376549  0.02091849 0.02528221]
# -- (180, 320, 3) [0.98562914 0.14734325 0.04661218]
# -- (180, 320, 3) [0.98972222 0.00618056 0.        ]
# -- (180, 320, 3) [1.         0.99993896 0.        ]
# -- (180, 320, 3) [0.9360132  0.02284797 0.02629022]
# -- (180, 320, 3) [0.98951095 0.16085708 0.04659186]
# -- (180, 320, 3) [0.98972222 0.         0.00618056]
# -- (180, 320, 3) [1.         0.         0.99993896]
# -- (180, 320, 3) [0.93659735 0.02069682 0.02809992]
# -- (180, 320, 3) [0.9856066  0.04924724 0.17048891]
# -- (180, 320, 3) [0.98972222 0.00618056 0.        ]
# -- (180, 320, 3) [1.         0.99993896 0.        ]
# -- (180, 320, 3) [0.9395856  0.02292816 0.02652866]
# -- (180, 320, 3) [0.9859922  0.16375728 0.04900199]

# %%
print("TEST")
print(x_test.shape)
y_predf=model.predict(x_test)
print(np.max(y_pred,axis=(0,1,2,3)))
#y_pred=y_predf>0.5
#y_dif=np.abs(y_pred-y_test)
# Out:
# TEST
# (20, 180, 320, 3)
# 0.9816217

# %%
plt.figure(1,figsize=(25,50))
for i in range(5):
    idx=random.randint(0,x_test.shape[0]-1)
    #print(np.max(y_predf[idx]))
    #print(np.sum(y_dif[idx]/(height_o*width_o)))
    plt.subplot(10, 3, i*3+1)
    plt.imshow(x_test[idx].reshape(height_i,width_i,3))
    #plt.show()
    plt.subplot(10, 3, i*3+2)
    plt_img(x_test[idx],y_test[idx])
    #plt.show()
    plt.subplot(10, 3, i*3+3)
    plt_img(x_test[idx],y_predf[idx])
    print(np.max(y_predf,axis=(0,1,2)))
plt.show()
# Out:
# -- (180, 320, 3) [0.99076389 0.         0.005     ]
# -- (180, 320, 3) [0.    0.    0.005]
# -- (180, 320, 3) [0.9363541  0.04335045 0.05841575]
# -- (180, 320, 3) [0.         0.04335045 0.05841575]
# [0.9791062  0.24749759 0.12543659]
# -- (180, 320, 3) [0.98819444 0.00578174 0.        ]
# -- (180, 320, 3) [0.         0.00578174 0.        ]
# -- (180, 320, 3) [0.9345193  0.04327504 0.05803012]
# -- (180, 320, 3) [0.         0.04327504 0.05803012]
# [0.9791062  0.24749759 0.12543659]
# -- (180, 320, 3) [0.98152778 0.         0.01      ]
# -- (180, 320, 3) [0.   0.   0.01]
# -- (180, 320, 3) [0.91194284 0.04478553 0.05928488]
# -- (180, 320, 3) [0.         0.04478553 0.05928488]
# [0.9791062  0.24749759 0.12543659]
# -- (180, 320, 3) [0.98930556 0.         0.00583333]
# -- (180, 320, 3) [0.         0.         0.00583333]
# -- (180, 320, 3) [0.93183815 0.04354821 0.05898115]
# -- (180, 320, 3) [0.         0.04354821 0.05898115]
# [0.9791062  0.24749759 0.12543659]
# -- (180, 320, 3) [0.99368056 0.         0.00305934]
# -- (180, 320, 3) [0.         0.         0.00305934]
# -- (180, 320, 3) [0.93630743 0.04258109 0.05711414]
# -- (180, 320, 3) [0.         0.04258109 0.05711414]
# [0.9791062  0.24749759 0.12543659]

# %%
idx=random.randint(0,x_test.shape[0])
i=obj.dataset.images.image[idx]
imgfile=os.path.join(basepath,i['file'])
print(imgfile)
img=cv2.imread(imgfile)
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)/255
img=cv2.resize(img,(320*2,180*2))
#img=cv2.resize(img,(720,512))
nf=3
plt.figure(1,figsize=(nf*2,nf*4))
for i in range(0,nf):
    print(img.shape)
    plt.subplot(nf, 2, i*2+1)
    plt.imshow(img)
    y_predf=model.predict(img.reshape(1,img.shape[0],img.shape[1],img.shape[2]))
    #print(y_predf.shape)
    plt.subplot(nf, 2, i*2+2)
    plt_img(img,y_predf[0])
    sx=int(img.shape[1]*0.5)
    sy=int(img.shape[0]*0.5)
    print(sx,sy)
    if sx%2==1: 
        sx-=1
    if sy%2==1: 
        sy-=1
    print(sx,sy)
    img=cv2.resize(img,(sx,sy))
plt.show()
# Out:
# /home/francisco/datasets/datasets/pictures/indoor_object_detection_dataset/faster_bounding_box_dataset/all/frame_s1_119.jpg
# (360, 640, 3)
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-20-0f6e5c0addde> in <module>
#      13     plt.subplot(nf, 2, i*2+1)
#      14     plt.imshow(img)
# ---> 15     y_predf=model.predict(img.reshape(1,img.shape[0],img.shape[1],img.shape[2]))
#      16     #print(y_predf.shape)
#      17     plt.subplot(nf, 2, i*2+2)
#
# ~/anaconda3/envs/dml3.8/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1627           for step in data_handler.steps():
#    1628             callbacks.on_predict_batch_begin(step)
# -> 1629             tmp_batch_outputs = self.predict_function(iterator)
#    1630             if data_handler.should_sync:
#    1631               context.async_wait()
#
# ~/anaconda3/envs/dml3.8/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/anaconda3/envs/dml3.8/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     860       # In this case we have not created variables on the first call. So we can
#     861       # run the first trace but we should fail if variables are created.
# --> 862       results = self._stateful_fn(*args, **kwds)
#     863       if self._created_variables:
#     864         raise ValueError("Creating variables on a non-first call to a function"
#
# ~/anaconda3/envs/dml3.8/lib/python3.8/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2940       (graph_function,
#    2941        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2942     return graph_function._call_flat(
#    2943         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2944
#
# ~/anaconda3/envs/dml3.8/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1916         and executing_eagerly):
#    1917       # No tape is watching; skip to running the function.
# -> 1918       return self._build_call_outputs(self._inference_function.call(
#    1919           ctx, args, cancellation_manager=cancellation_manager))
#    1920     forward_backward = self._select_forward_and_backward_functions(
#
# ~/anaconda3/envs/dml3.8/lib/python3.8/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     553       with _InterpolateFunctionError(self):
#     554         if cancellation_manager is None:
# --> 555           outputs = execute.execute(
#     556               str(self.signature.name),
#     557               num_outputs=self._num_outputs,
#
# ~/anaconda3/envs/dml3.8/lib/python3.8/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# InvalidArgumentError:  Conv2DSlowBackpropInput: Size of out_backprop doesn't match computed: actual = 90, computed = 45 spatial_dim: 2 input: 90 filter: 2 output: 90 stride: 2 dilation: 1
# 	 [[node model/conv2d_transpose/conv2d_transpose (defined at <ipython-input-19-8a8223f9f0e3>:15) ]] [Op:__inference_predict_function_7421]
#
# Function call stack:
# predict_function

# %%
y_predf=model.predict(img.reshape(1,img.shape[0],img.shape[1],img.shape[2]))
print(img.shape)
print(y_predf.shape)
# Out:
# (32, 64, 3)
# (1, 32, 64, 3)

# %%
#plt.imshow(y_predf[0].reshape(y_predf.shape[1],y_predf.shape[2],3))
plt_img(img,y_predf[0])

plt.show()
